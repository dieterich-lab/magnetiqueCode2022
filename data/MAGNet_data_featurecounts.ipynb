# %% [markdown]
# ## MAGNet Data
#
# ### Bulk RNA-seq
#
# Data cleaning, outlier removal, etc.

# %%
library(dplyr)
library(stringr)

library(loomR)
library(rrcov)

# %%
options(repr.plot.width=12, repr.plot.height=8)

# %%
# prep data

parentDir <- '/prj/MAGE'
dataDir <- file.path(parentDir, 'analysis', 'data', fsep=.Platform$file.sep)

ctsFile <- file.path(dataDir, 'featurecounts.rds', fsep=.Platform$file.sep)
traitsFile <- file.path(dataDir, 'MAGE_metadata.txt', fsep=.Platform$file.sep)
dedupFile <- file.path(parentDir, 'Christoph', 'mage_dedup_metrics_final.txt', fsep=.Platform$file.sep) # CD

cts <- readRDS(ctsFile)$counts
colnames(cts) <- str_split(string = colnames(cts), pattern = '\\.', simplify = T)[, 6]

# %%
datTraits <- read.csv(traitsFile, stringsAsFactors = FALSE)
datTraits <- datTraits[c('Run', 'etiology', 'race', 'Age', 'sex')]
colnames(datTraits) <- c('Run', 'Etiology', 'Race', 'Age', 'Sex')
datTraits <- datTraits[datTraits$Etiology != '',]
datTraits$Etiology <- str_sub(datTraits$Etiology, start = 1, end = 1)
datTraits[datTraits$Etiology=='D',]$Etiology <- 'DCM'
datTraits[datTraits$Etiology=='H',]$Etiology <- 'HCM'
datTraits[datTraits$Etiology=='N',]$Etiology <- 'NFD'
datTraits[datTraits$Etiology=='P',]$Etiology <- 'PPCM'
datTraits$Etiology <- relevel(as.factor(datTraits$Etiology), ref='NFD')
datTraits[datTraits$Race=='African American',]$Race <- 'AA'
datTraits[datTraits$Race=='Caucasian',]$Race <- 'C'
datTraits$Race <- relevel(as.factor(datTraits$Race), ref='C')
datTraits[datTraits$Sex=='female',]$Sex <- 'F'
datTraits[datTraits$Sex=='male',]$Sex <- 'M'
datTraits$Sex <- relevel(as.factor(datTraits$Sex), ref='M')

# %%
idx <- intersect(datTraits$Run, colnames(cts))
datTraits <- datTraits[na.omit(match(idx, datTraits$Run)),]
cts <- cts[,na.omit(match(idx, colnames(cts)))]

dedup <- read.table(dedupFile, as.is=T, header=F)
dedup <- dedup[,c(1,3)]
dedup[,1] <- gsub(".metrics.txt-Unknown","", dedup[,1])
colnames(dedup) <- c("Run","DuplicationRate")
datTraits <- merge(datTraits, dedup, by.x='Run', by.y='Run')
rownames(datTraits) <- datTraits$Run

ins <- intersect(rownames(datTraits), colnames(cts))
datTraits <- datTraits[ins, ]
cts <- cts[, ins]

# stopifnot(all(datTraits$Run == colnames(cts)))
all(rownames(datTraits)==colnames(cts))
# Out:
# [1] TRUE

# %%
# gene-level filtering

varQuant <- 0.01
countQuant <- 0.01

# raw threshold
chk <- cts[rowSums(cts) > 10, ]
# threshold on variance: remove varQuant% of genes with lowest variance
var.all <- apply(chk, 1, var)
chk <- chk[var.all > quantile(var.all, probs=varQuant, type=8), ]
# threshold on normalised counts: remove countQuant% of genes with lowest
# (sequencing-depth normalised) average expression
sf <- DESeq2::estimateSizeFactorsForMatrix(chk)
cts.norm <- t(t(chk)/sf)
keep <- rowMeans(cts.norm) > quantile(rowMeans(cts.norm), probs=countQuant, type=8)
chk <- chk[keep,]

background <- rownames(cts)
universe <- background %in% background
selection <- background %in% rownames(chk)
genes <- factor(as.integer(selection[universe]))
names(genes) <- background

# %%
# sample-level filtering (outlier removal)
# currently do not remove any, but see below

samples <- rep(1, dim(cts)[2])
names(samples) <- colnames(cts)
samples <- as.factor(samples)

# %%
# write loom file
gene.attrs <- list(GeneFlag=genes)
cell.attrs <- list(SampleFlag=samples,
                   Run=datTraits$Run,
                   Etiology=datTraits$Etiology,
                   Race=datTraits$Race,
                   Age=datTraits$Age,
                   Sex=datTraits$Sex,
                   DuplicationRate=datTraits$DuplicationRate)

filename <- file.path(dataDir, 'MAGNet_data.loom', fsep=.Platform$file.sep)
create(filename, 
       cts, 
       gene.attrs=gene.attrs, 
       cell.attrs=cell.attrs,
       do.transpose=TRUE,
       calc.numi=FALSE)

# ISSUE: https://github.com/mojaveazure/loomR/issues/38
# we already have installed the latest dev version...
# write loom file, add gene flag separately, and re-create with loompy
write.csv(genes, file.path(dataDir, 'tmp.csv'), row.names = T)

# import os
# import pandas as pd
# import loompy as lp
# dataloc = '/prj/MAGE/analysis/data'
# lf = lp.connect(os.path.join(dataloc, 'MAGNet_data.loom'), mode='r+', validate=False)
# x = pd.read_csv(os.path.join(dataloc, 'tmp.csv'), index_col=0)
# row_attrs = {}
# for key, value in lf.ra.items():
#     row_attrs[key] = value
# row_attrs['GeneFlag'] = cts['x'].values
# col_attrs = {}
# for key, value in lf.ca.items():
#     col_attrs[key] = value 
# lp.create(os.path.join(dataloc, 'MAGNet_data.loom'),
#     lf[:,:], # copying the expression matrix from the open loom connection
#     row_attrs=row_attrs, 
#     col_attrs=col_attrs)
# lf.close()
# Out:
# Transposing input data: loom file will show input columns (cells) as rows and input rows (features) as columns
#
# This is to maintain compatibility with other loom tools
#   |======================================================================| 100%
# Adding: CellID
#
# Adding: Gene
#
# Adding: SampleFlag
#
# Adding: Run
#
# Adding: Etiology
#
# Adding: Race
#
# Adding: Age
#
# Adding: Sex
#
# Adding: DuplicationRate
# Class: loom
# Filename: /beegfs/prj/MAGE/analysis/data/MAGNet_data.loom
# Access type: H5F_ACC_RDWR
# Attributes: version, chunks, LOOM_SPEC_VERSION, last_modified
# Listing:
#        name    obj_type dataset.dims dataset.type_class
#   col_attrs   H5I_GROUP         <NA>               <NA>
#  col_graphs   H5I_GROUP         <NA>               <NA>
#      layers   H5I_GROUP         <NA>               <NA>
#      matrix H5I_DATASET  360 x 58884        H5T_INTEGER
#   row_attrs   H5I_GROUP         <NA>               <NA>
#  row_graphs   H5I_GROUP         <NA>               <NA>

# %%
file.remove(file.path(dataDir, 'tmp.csv'))
# Out:
# [1] TRUE

# %%
lfile <- connect(filename=file.path(dataDir, 'MAGNet_data.loom'), mode="r+", skip.validate=TRUE)
lfile
lfile$close_all()
# Out:
# Warning message in .subset2(public_bind_env, "initialize")(...):
# “Skipping validation step, some fields are not populated”
# Class: loom
# Filename: /beegfs/prj/MAGE/analysis/data/MAGNet_data.loom
# Access type: H5F_ACC_RDWR
# Attributes: last_modified, version
# Listing:
#        name    obj_type dataset.dims dataset.type_class
#       attrs   H5I_GROUP         <NA>               <NA>
#   col_attrs   H5I_GROUP         <NA>               <NA>
#  col_graphs   H5I_GROUP         <NA>               <NA>
#      layers   H5I_GROUP         <NA>               <NA>
#      matrix H5I_DATASET  360 x 58884        H5T_INTEGER
#   row_attrs   H5I_GROUP         <NA>               <NA>
#  row_graphs   H5I_GROUP         <NA>               <NA>

# %%
# add as RData 
save(cts, cell.attrs, gene.attrs, file=file.path(dataDir, 'MAGNet_data.RData'))

# %%
# ############################################################################################################
# sample analysis

# %%
library(ggplot2)
library("RColorBrewer")

plot_pca <- function(datExpr, datTraits) {  
    # in case we have zero variance for some genes...
    tt <- t(datExpr)
    d1 <- dim(tt)[2]
    tt <- tt[ , apply(tt, 2, var) != 0]
    d2 <- dim(tt)[2]
    if (d1 != d2) {
        print(paste("Removed ", d1-d2, "genes with zero variance before PCA", sep=""))
    }
    pcaData <- prcomp(tt, scale=T)
    # determine the proportion of variance of each component
    percentVar <- round(100*pcaData$sdev^2/sum(pcaData$sdev^2), 1)
    # create data frame
    pca.df <- data.frame(pc1=pcaData$x[,1], 
                         pc2=pcaData$x[,2],
                         datTraits[,c('Race', 'Age', 'Sex', 'Etiology')])
    # age as factor
    pca.df$qage <- cut(pca.df$Age, 
                       breaks = quantile(pca.df$Age, by=0.25), 
                       include.lowest = TRUE)
    d <- tidyr::pivot_longer(pca.df, cols = c('Race', 'Sex', 'qage', 'Etiology'), names_to='traits')

    ggplot(data=d, aes_string(x='pc1', y='pc2', color='value')) + 
        geom_point(size=2) + 
        xlab(paste0("PC1: explaining ", percentVar[1], "% of variance")) +
        ylab(paste0("PC2: explaining ", percentVar[2], "% of variance")) +
        facet_wrap(~traits) +
        cowplot::theme_cowplot()
}

# %%
# rlog is more robust and sometimes performs qualitatively better than the vst which is useful 
# when checking for outliers, e.g. more false positive outliers were reported by PcaGrid when 
# vst was used for normalization than when rlog transformation was used.
# However, rlog is significantly slower with many samples...
# the vst speed-up is accomplished by subsetting to a smaller number of genes to estimate
# the dispersion trend

# It uses the design formula to calculate the within-group variability (if blind=FALSE) or the 
# across-all-samples variability (if blind=TRUE). 

cts_vst <- DESeq2::vst(cts, blind=TRUE) # increase nsub ?

chk_vst <- DESeq2::vst(chk, blind=TRUE) # increase nsub ?

# %%
# https://bmcbioinformatics.biomedcentral.com/articles/10.1186/s12859-020-03608-0

# restrict to 10 PCs
# NOTE: default crit.pca.distances = 0.975
pc <- PcaGrid(t(chk_vst), k=10)

# %%
par(mfrow=c(1,2))
plot(pc$eigenvalues)
plot(pc$sd, pc$od)
abline(v=pc$cutoff.sd)
abline(h=pc$cutoff.od)
# Out:
# plot without title

# %%
# remove outliers - PcaGrid
outliers <- names(pc$flag[pc$flag==FALSE]) # The regular observations receive a flag 1 (TRUE)
clean <- chk_vst[,!(colnames(chk_vst) %in% outliers)]
meta <- datTraits[!(rownames(datTraits) %in% outliers),]
print(paste("Removed ", dim(cts)[2]-dim(clean)[2], " samples", sep=""))
# Out:
# [1] "Removed 35 samples"

# %%
plot_pca(clean, meta)
# Out:
# plot without title

# %%
# hierarchical clustering
d <- dist(t(scale(chk_vst)), method = "euclidean")
clust <- hclust(d, method = "average" )
# plot(hc1, cex = 0.6, hang = -1)

# %%
plot(clust, 
     main = "Sample clustering to detect outliers", 
     sub="", 
     xlab="", 
     cex.lab = 1.5, 
     cex.axis = 1.5, 
     cex.main = 2)
abline(h = 45, col = "red")
# Out:
# Plot with title “Sample clustering to detect outliers”

# %%
static <- WGCNA::cutreeStatic(clust, cutHeight=45, minSize=6)
table(static)
# table(cutree(clust, h=80)) # difficult to detect which cluster(s) is/are outlier(s) -> 6 PPCM
# Out:
# static
#   0   1   2   3   4
#  16 247  81  10   6

# %%
# keepSamples <- (!static==0)
# keepSamples <- (static==1 | static==2)
keepSamples <- (static==1)
clean <- chk_vst[,keepSamples]
meta <- datTraits[keepSamples,]
print(paste("Removed ", dim(cts)[2]-dim(clean)[2], " samples", sep=""))
# Out:
# [1] "Removed 113 samples"

# %%
plot_pca(clean, meta)
# Out:
# plot without title

# %%
# samples used for WGN analysis
attach("/prj/MAGE/analysis/wgcna/data/MAGEfeaturecounts.input.RData")
used <- rownames(datExpr)
clean <- chk_vst[,(colnames(chk_vst) %in% used)]
meta <- datTraits[(rownames(datTraits) %in% used),]
print(paste("Removed ", dim(cts)[2]-dim(clean)[2], " samples", sep=""))
# Out:
# The following object is masked _by_ .GlobalEnv:
#
#     datTraits
# [1] "Removed 103 samples"

# %%
plot_pca(clean, meta)
# Out:
# plot without title

# %%
# all samples - gene filtering
plot_pca(chk_vst, datTraits[(rownames(datTraits) %in% colnames(chk_vst)),])
# Out:
# plot without title

# %%
# all samples - all genes
plot_pca(cts_vst, datTraits)
# Out:
# [1] "Removed 8442genes with zero variance before PCA"
# plot without title

# %%
filename <- file.path(dataDir, 'cts_vst.csv')
write.csv(cts_vst, filename, row.names = T)

# %%
# import umap
# import pandas as pd

# import seaborn as sns
# import matplotlib.pyplot as plt

# runUmap = umap.UMAP(n_neighbors=15, 
#                     min_dist=0.5, 
#                     n_components=2,
#                     metric='euclidean').fit_transform

# cts = pd.read_csv(os.path.join(dataDir, 'cts_vst.csv'), index_col=0)
# dr_umap = runUmap(cts.T)
# dr_umap = pd.DataFrame(dr_umap, columns=['X', 'Y'], index=list(cts))

# fig, (ax1,ax2,ax3) = plt.subplots(1,3, figsize=(16,8), dpi=150)

# drplot(dr_umap, colorlab=meta['Etiology'], ax=ax1, s=2, title='Etiology')
# drplot(dr_umap, colorlab=meta['Race'], ax=ax2, s=2, title='Race')
# drplot(dr_umap, colorlab=meta['Sex'], ax=ax3, s=2, title='Sex')

# ax1.legend(loc='right', bbox_to_anchor=(1.25, 0.15), ncol=1, markerscale=2,
#            fontsize='x-large', frameon=False, title=None)
# fig.tight_layout()
# fig.savefig(os.path.join(dataDir, 'umap_all.pdf') , dpi=600, bbox_inches='tight')

# %%
file.remove(file.path(dataDir, 'cts_vst.csv'))
# Out:
# [1] TRUE

# %%
sessionInfo()
# Out:
# R version 3.5.1 (2018-07-02)
# Platform: x86_64-pc-linux-gnu (64-bit)
# Running under: Debian GNU/Linux 8 (jessie)
#
# Matrix products: default
# BLAS: /beegfs/biosw/R/3.5.1/lib/R/lib/libRblas.so
# LAPACK: /beegfs/biosw/R/3.5.1/lib/R/lib/libRlapack.so
#
# locale:
#  [1] LC_CTYPE=en_IE.UTF-8       LC_NUMERIC=C
#  [3] LC_TIME=en_IE.UTF-8        LC_COLLATE=en_IE.UTF-8
#  [5] LC_MONETARY=en_IE.UTF-8    LC_MESSAGES=en_IE.UTF-8
#  [7] LC_PAPER=en_IE.UTF-8       LC_NAME=C
#  [9] LC_ADDRESS=C               LC_TELEPHONE=C
# [11] LC_MEASUREMENT=en_IE.UTF-8 LC_IDENTIFICATION=C
#
# attached base packages:
# [1] stats     graphics  grDevices utils     datasets  methods   base
#
# other attached packages:
# [1] RColorBrewer_1.1-2 ggplot2_3.3.2      rrcov_1.5-5        robustbase_0.93-6
# [5] loomR_0.2.1.9000   hdf5r_1.3.3        R6_2.4.1           stringr_1.4.0
# [9] dplyr_1.0.2
#
# loaded via a namespace (and not attached):
#   [1] bitops_1.0-6                matrixStats_0.56.0
#   [3] bit64_4.0.5                 doParallel_1.0.15
#   [5] GenomeInfoDb_1.18.2         dynamicTreeCut_1.63-1
#   [7] repr_1.1.0                  tools_3.5.1
#   [9] backports_1.1.10            rpart_4.1-13
#  [11] Hmisc_4.4-1                 DBI_1.1.0
#  [13] BiocGenerics_0.28.0         colorspace_1.4-1
#  [15] nnet_7.3-12                 withr_2.2.0
#  [17] tidyselect_1.1.0            gridExtra_2.3
#  [19] DESeq2_1.22.2               preprocessCore_1.44.0
#  [21] bit_4.0.4                   compiler_3.5.1
#  [23] WGCNA_1.69                  Biobase_2.42.0
#  [25] htmlTable_2.1.0             DelayedArray_0.8.0
#  [27] labeling_0.3                scales_1.1.1
#  [29] checkmate_2.0.0             DEoptimR_1.0-8
#  [31] mvtnorm_1.1-1               genefilter_1.64.0
#  [33] pbapply_1.4-3               pbdZMQ_0.3-3
#  [35] digest_0.6.25               foreign_0.8-70
#  [37] XVector_0.22.0              base64enc_0.1-3
#  [39] pkgconfig_2.0.3             htmltools_0.5.0
#  [41] htmlwidgets_1.5.1           rlang_0.4.10
#  [43] impute_1.56.0               rstudioapi_0.11
#  [45] RSQLite_2.2.0               farver_2.0.3
#  [47] generics_0.0.2              jsonlite_1.7.1
#  [49] BiocParallel_1.16.6         RCurl_1.98-1.2
#  [51] magrittr_1.5                GO.db_3.7.0
#  [53] GenomeInfoDbData_1.2.0      Formula_1.2-3
#  [55] Matrix_1.2-14               Rcpp_1.0.5
#  [57] IRkernel_1.1.1              munsell_0.5.0
#  [59] S4Vectors_0.20.1            lifecycle_0.2.0
#  [61] stringi_1.5.3               SummarizedExperiment_1.12.0
#  [63] zlibbioc_1.28.0             grid_3.5.1
#  [65] blob_1.2.1                  parallel_3.5.1
#  [67] crayon_1.3.4                lattice_0.20-35
#  [69] IRdisplay_0.7.0             cowplot_1.1.0
#  [71] splines_3.5.1               annotate_1.60.1
#  [73] locfit_1.5-9.4              knitr_1.29
#  [75] pillar_1.4.6                fastcluster_1.1.25
#  [77] GenomicRanges_1.34.0        uuid_0.1-4
#  [79] codetools_0.2-15            geneplotter_1.60.0
#  [81] stats4_3.5.1                XML_3.99-0.3
#  [83] glue_1.4.2                  evaluate_0.14
#  [85] latticeExtra_0.6-28         data.table_1.13.0
#  [87] foreach_1.5.0               vctrs_0.3.4
#  [89] gtable_0.3.0                purrr_0.3.4
#  [91] tidyr_1.1.2                 xfun_0.17
#  [93] xtable_1.8-4                survival_3.2-3
#  [95] pcaPP_1.9-73                tibble_3.0.3
#  [97] iterators_1.0.12            AnnotationDbi_1.44.0
#  [99] memoise_1.1.0               IRanges_2.16.0
# [101] cluster_2.0.7-1             ellipsis_0.3.1

# %% [markdown]
# ## MAGNet - PVCA
#
# R4.0.5

# %%
library(dplyr)
library(stringr)
library("SummarizedExperiment")

options(repr.plot.width=16, repr.plot.height=10)

# %% [markdown]
# ### Download data to preferred directory
#
# ```
# #!/bin/sh
# wget --output-document data.zip 'https://data.dieterichlab.org/s/3gCTLGT4DaAqaqb/download' --header 'Accept: text/html' --header 'Connection: keep-alive'
# unzip -o data.zip
# rm data.zip
# rm MAGNetApp/magnetique.sqlite MAGNetApp/data/colData.txt
# rm -r MAGNetApp/data/DGE MAGNetApp/data/DTU MAGNetApp/data/networks MAGNetApp/data/RBP
# ```

# %%
dirloc <- '/prj/MAGE/analysis/genetonic/PVCA'

load(file.path(dirloc, 'MAGNetApp', 'data', 'MAGNet.RData'))

colData$AFib <- factor(colData$AFib, levels=c("No", "Yes"))
colData$VTVF <- factor(colData$VTVF, levels=c("No", "Yes"))
colData$Diabetes <- factor(colData$Diabetes, levels=c("No", "Yes"))
colData$Hypertension <- factor(colData$VTVF, levels=c("No", "Yes"))
colData$LibraryPool <- factor(colData$LibraryPool)

# %%
head(colData)
all.equal(colnames(countData), rownames(colData))
dim(countData)
# Out:
#        Run         Experiment LibraryPool TIN      RIN DuplicationRate
# C00039 SRR10676821 SRX7354049 Magnet_10   72.76478 8.4 0.321948
# C00055 SRR10676822 SRX7354050 Magnet_11   74.29391 9.1 0.461090
# C00074 SRR10676823 SRX7354051 Magnet_09   77.44517 7.8 0.338003
# C00085 SRR10676824 SRX7354319 Magnet_06   69.51659 9.4 0.420441
# C00105 SRR10676825 SRX7354320 Magnet_03   73.60743 8.8 0.290037
# C00120 SRR10676826 SRX7354321 Magnet_12   30.35077 8.6 0.595905
#        TissueSource Etiology Race Age Sex Weight Height HW  LVMass AFib VTVF
# C00039 NF           NFD      AA   18  M   70     175     NA NA     No   No
# C00055 NF           NFD      AA   26  M   85     183     NA NA     No   No
# C00074 NF           NFD      AA   17  M   68     173    400 NA     No   No
# C00085 NF           NFD      AA   59  F   66     157    380 NA     No   No
# C00105 NF           NFD      AA   59  F   87     157     NA NA     No   No
# C00120 NF           NFD      C    50  M   87     175    640 NA     No   No
#        Diabetes Hypertension LVEF
# C00039 No       No           0.37
# C00055 No       No             NA
# C00074 No       No           0.27
# C00085 No       No           0.60
# C00105 No       No           0.55
# C00120 No       No           0.65
# [1] TRUE
# [1] 41886   354

# %% [markdown]
# ### We try to see how the inferred surrogate variables correlate with the covariates that we did not include in the model...

# %%
library(sva)

# %%
findDeseqFactorsSingle <- function(count_data)
{
  loggeomeans <- rowMeans(log(count_data))
  deseqFactors <- apply(count_data, 2, deseq, loggeomeans = loggeomeans) 
  deseqFactors
}

deseq <- function(x, loggeomeans) {
  finitePositive <- is.finite(loggeomeans) & x > 0
  if (any(finitePositive)) {
    res <- exp(median((log(x) - loggeomeans)[finitePositive], na.rm = TRUE))
  } else {
    print(utils::head(x))
    stop("Can't normalise accross a condition.
         Too many zero expressed genes. ")
  }
  res
}

sizeFactors <- findDeseqFactorsSingle(countData)
normData <- t(t(countData) / findDeseqFactorsSingle(countData))

# %%
# full model
# including both the adjustment variables and the variable of interest (here we assume none)
# ~Etiology+LibraryPool+TIN+RIN+DuplicationRate+Race+Age+Sex+Weight+Height+HW+AFib+VTVF+Diabetes+Hypertension+LVEF
mod = model.matrix(~Etiology, data=colData)

# null model
# only the adjustment variables
mod0 <- model.matrix(~1,data=colData)

# %%
# estimate number of latent factors
# n.sv = num.sv(normData, mod, method="leek")

# skip and fix for now to be the number of real adjustment variables (drop LVMass)
n.sv <- 5

# fix number of surrogate variables...
svseq <- svaseq(normData, mod, mod0, n.sv = n.sv)

# sv is a matrix whose columns correspond to the estimated surrogate variables (can be used in downstream analyses)
# pprob.gam is the posterior probability that each gene is associated with one or more latent variables
# pprob.b is the posterior probability that each gene is associated with the variables of interest
# Out:
# Number of significant surrogate variables is:  5
# Iteration (out of 5 ):1  2  3  4  5

# %%
# Because we actually do know the real variables (assuming there are no other sources of variation), 
# we can see how well the SVA method did at recovering these variables

# %%
for (n in c('LibraryPool', 'TIN', 'RIN', 'DuplicationRate', 'Race', 'Age', 'Sex', 'Weight', 'Height', 'HW', 'AFib', 'VTVF', 'Diabetes', 'Hypertension', 'LVEF')){
   png(file.path(dirloc, paste(n, 'SVA5.png', sep='-')), width=600, height=350)
    par(mfrow = c(2, 3), mar = c(3,5,3,1))
    for (i in 1:n.sv) {
      stripchart(svseq$sv[, i] ~ colData[[n]], vertical = TRUE, main = paste0("SV", i))
      abline(h = 0)
     }
   dev.off()
}

# %% [markdown]
# ### PVCA

# %%
# based on https://bioconductor.statistik.tu-dortmund.de/packages/3.7/workflows/vignettes/ExpressionNormalizationWorkflow

library(Biobase)
library(limma)
library(lme4)
library(matrixStats)
library(pvca)
library(vsn)

expSetobj <- function(expression, covariates, cov_desc=NULL)
{
    expression <- as.matrix(expression)
    if(is.null(cov_desc)) {
        cov_desc <- colnames(covariates)
    }
    metadata <- data.frame(labelDescription=cov_desc, 
                           row.names=colnames(covariates))
    phenoData <- new("AnnotatedDataFrame", data=covariates,
                     varMetadata=metadata)
    exp_datObj <- ExpressionSet(assayData=expression, phenoData=phenoData)
    return(exp_datObj)
}


## PVCA by Pierre R.Bushel and Jianying Li
pvcaBatchAssess <- function (abatch, batch_factors, threshold)
{
    theDataMatrix <- exprs(vsn2(abatch, verbose=FALSE))
    dataRowN <- nrow(theDataMatrix)
    dataColN <- ncol(theDataMatrix)
    theDataMatrixCentered <- matrix(data=0, nrow=dataRowN,
                                    ncol=dataColN)
    theDataMatrixCentered_transposed <- apply(theDataMatrix, 1,
                                             scale, center=TRUE, scale=FALSE)
    theDataMatrixCentered <- t(theDataMatrixCentered_transposed)
    theDataCor <- cor(theDataMatrixCentered)
    eigenData <- eigen(theDataCor)
    eigenValues <- eigenData$values
    ev_n <- length(eigenValues)
    eigenVectorsMatrix <- eigenData$vectors
    eigenValuesSum <- sum(eigenValues)
    percents_PCs <- eigenValues / eigenValuesSum
    expInfo <- pData(abatch)[, batch_factors]
    exp_design <- as.data.frame(expInfo)
    expDesignRowN <- nrow(exp_design)
    expDesignColN <- ncol(exp_design)
    my_counter_2 <- 0
    my_sum_2 <- 1
    for (i in ev_n:1) {
        my_sum_2 <- my_sum_2 - percents_PCs[i]
        if ( (my_sum_2) <= threshold) {
            my_counter_2 <- my_counter_2 + 1
        }
    }
    if (my_counter_2 < 3) {
        pc_n <- 3
    }
    else {
        pc_n <- my_counter_2
    }
    pc_data_matrix <- matrix(data=0, nrow= (expDesignRowN *
                                                   pc_n), ncol=1)
    mycounter <- 0
    for (i in 1:pc_n) {
        for (j in 1:expDesignRowN) {
            mycounter <- mycounter + 1
            pc_data_matrix[mycounter, 1] <- eigenVectorsMatrix[j,i]
        }
    }
    AAA <- exp_design[rep(1:expDesignRowN, pc_n), ]
    Data <- cbind(AAA, pc_data_matrix)
    variables <- c(colnames(exp_design))
    for (i in 1:length(variables)) {
        Data$variables[i] <- as.factor(Data$variables[i])
    }
    op <- options(warn= (-1))
    effects_n <- expDesignColN + 1  
    randomEffectsMatrix <- matrix(data=0, nrow=pc_n, ncol=effects_n)
    model.func <- c()
    index <- 1
    for (i in 1:length(variables)) {
        mod <- paste("(1|", variables[i], ")", sep="")
        model.func[index] <- mod
        index <- index + 1
    }
    function.mods <- paste(model.func, collapse=" + ")
    for (i in 1:pc_n) {
        y <- (((i - 1) * expDesignRowN) + 1)
        funct <- paste("pc_data_matrix", function.mods, sep=" ~ ")
        Rm1ML <- lmer(funct, Data[y: ( ( (i - 1) * expDesignRowN) +
                     expDesignRowN), ], REML=TRUE, verbose=FALSE,
                            na.action=na.omit)
        randomEffects <- Rm1ML
        randomEffectsMatrix[i, ] <- c(unlist(VarCorr(Rm1ML)),
                                      resid=sigma(Rm1ML)^2)
    }
    effectsNames <- c(names(getME(Rm1ML, "cnms")), "resid")
    randomEffectsMatrixStdze <- matrix(data=0, nrow=pc_n,
                                       ncol=effects_n)
    for (i in 1:pc_n) {
        mySum <- sum(randomEffectsMatrix[i, ])
        for (j in 1:effects_n) {
            randomEffectsMatrixStdze[i, j] <- randomEffectsMatrix[i,
                                                                 j] / mySum
        }
    }
    randomEffectsMatrixWtProp <- matrix(data=0, nrow=pc_n,
                                        ncol=effects_n)
    for (i in 1:pc_n) {
        weight <- eigenValues[i] / eigenValuesSum
        for (j in 1:effects_n) {
            randomEffectsMatrixWtProp[i, j] <- randomEffectsMatrixStdze[i,j] * weight
        }
    }
    randomEffectsSums <- matrix(data=0, nrow=1, ncol=effects_n)
    randomEffectsSums <- colSums(randomEffectsMatrixWtProp)
    totalSum <- sum(randomEffectsSums)
    randomEffectsMatrixWtAveProp <- matrix(data=0, nrow=1,
                                           ncol=effects_n)
    for (j in 1:effects_n) {
        randomEffectsMatrixWtAveProp[j] <- randomEffectsSums[j] / totalSum
    }
    return(list(dat=randomEffectsMatrixWtAveProp, label=effectsNames))
}

snmAnaly <- function(exprs, cov, bv, av, iv, adj=TRUE)
{
    kar_rawdata <- exprs
    kar_bio.var <- as.data.frame(cov[,bv])
    kar_adj.var <- as.data.frame(cov[,av])
    rownames(kar_adj.var) <- rownames(cov)
    colnames(kar_adj.var) <- av
    kar_int.var <- as.data.frame(cov[,iv])
    colnames(kar_int.var) <- iv
    int.var <- kar_int.var
    int.var$Array <- as.factor(int.var$Array)
    adj.var <- model.matrix(~., kar_adj.var)
    bio.var <- model.matrix(~., kar_bio.var)
    raw.data <- as.matrix(kar_rawdata)
    snm.obj <- snm(raw.data, bio.var, adj.var, int.var, rm.adj=adj, num.iter=5)
    write.table(snm.obj$norm.dat, file="snm_normalized_data.csv", 
                sep=",", col.names=NA)
    return(snm.obj)
}


conTocat <- function(covariates, var_names)
{
    var <- covariates[,var_names]
    len <- dim(var)[2]
    for (i in 1:len) {
        temp <- as.numeric(with(var, cut(var[,i], breaks=
                          quantile(var[,i], probs=seq(0, 1, by=0.25)), 
                                                  include.lowest=TRUE)))
        covariates <- cbind(covariates, temp)
        colnames(covariates)[ncol(covariates)] <- 
                           paste(var_names[i], "_cat", sep="")
    }
    return(covariates)
}

# %% [markdown]
# PVCA (Bushel, 2013) estimates the proportion of the variance of the principal components of the gene expression data that can be attributed to each of the given covariates.The remaining fraction is assigned as “residual” variance.It efficiently combines principal component analysis (PCA) to reduce the feature space and variance component analysis (VCA) which fits a mixed linear model using factors of interest as random effects to estimate and partition the total variability. The variance explained is computed as a weighted average of the contributions of each factor to each PC, and you have the option of specifying how many principal components to include, by setting a threshold amount of the variance that needs to be explained by the identified PCs.

# %%
# we first need to categorize the continuous covariates

colData$TIN <- cut(colData$TIN, 
                   breaks = quantile(colData$TIN, by=0.25, na.rm = TRUE), 
                   include.lowest = TRUE)
colData$RIN <- cut(colData$RIN, 
                   breaks = quantile(colData$RIN, by=0.25, na.rm = TRUE), 
                   include.lowest = TRUE)
colData$DuplicationRate <- cut(colData$DuplicationRate, 
                   breaks = quantile(colData$DuplicationRate, by=0.25, na.rm = TRUE), 
                   include.lowest = TRUE)
colData$Age <- cut(colData$Age, 
                   breaks = quantile(colData$Age, by=0.25, na.rm = TRUE), 
                   include.lowest = TRUE)
colData$Weight <- cut(colData$Weight, 
                   breaks = quantile(colData$Weight, by=0.25, na.rm = TRUE), 
                   include.lowest = TRUE)
colData$Height <- cut(colData$Height, 
                   breaks = quantile(colData$Height, by=0.25, na.rm = TRUE), 
                   include.lowest = TRUE)
colData$HW <- cut(colData$HW, 
                   breaks = quantile(colData$HW, by=0.25, na.rm = TRUE), 
                   include.lowest = TRUE)
colData$LVEF <- cut(colData$LVEF, 
                   breaks = quantile(colData$LVEF, by=0.25, na.rm = TRUE), 
                   include.lowest = TRUE)

# %%
# and remove unused variables
colData <- colData[,-c(1,2,7,15)]

# %%
head(colData)
# Out:
#        LibraryPool TIN         RIN       DuplicationRate Etiology Race Age
# C00039 Magnet_10   (70.1,73.3] (8.1,8.5] [0.233,0.378]   NFD      AA   [15,48]
# C00055 Magnet_11   (73.3,81.5] (8.9,10]  (0.421,0.517]   NFD      AA   [15,48]
# C00074 Magnet_09   (73.3,81.5] [5.8,8.1] [0.233,0.378]   NFD      AA   [15,48]
# C00085 Magnet_06   (60.6,70.1] (8.9,10]  (0.378,0.421]   NFD      AA   (56,62]
# C00105 Magnet_03   (73.3,81.5] (8.5,8.9] [0.233,0.378]   NFD      AA   (56,62]
# C00120 Magnet_12   [23.4,60.6] (8.5,8.9] (0.517,0.935]   NFD      C    (48,56]
#        Sex Weight    Height    HW        AFib VTVF Diabetes Hypertension
# C00039 M   (66.2,79] (170,178] NA        No   No   No       No
# C00055 M   (79,91]   (178,196] NA        No   No   No       No
# C00074 M   (66.2,79] (170,178] (372,448] No   No   No       No
# C00085 F   [27,66.2] [55,163]  (372,448] No   No   No       No
# C00105 F   (79,91]   [55,163]  NA        No   No   No       No
# C00120 M   (79,91]   (170,178] (558,923] No   No   No       No
#        LVEF
# C00039 (0.2,0.52]
# C00055 NA
# C00074 (0.2,0.52]
# C00085 (0.52,0.8]
# C00105 (0.52,0.8]
# C00120 (0.52,0.8]

# %%
# convert to ExpressionSet
# inpData <- expSetobj(countData, colData)

# use norm - uncomment otherwise
sizeFactors <- findDeseqFactorsSingle(countData)
normData <- t(t(countData) / findDeseqFactorsSingle(countData))
inpData <- expSetobj(normData, colData)

# %%
# set the covariates whose effect size on the data needs to be calculated
cvrts_eff_var <- colnames(colData)
## PVCA Threshold Value is the percentile value of the minimum amount of the variabilities that the selected principal components need to explain, 
## here requiring 75% of the expression variance to be captured by the PCs
pct_thrsh <- 0.75 
## Perform the PVCA analysis
pvcaObj <- pvcaBatchAssess(inpData, cvrts_eff_var, pct_thrsh)

# note that the model is singular...
# we could try reducing the number of covariates, etc.? -> there is no straighforward solution though...
# Out:
# boundary (singular) fit: see ?isSingular
#
# boundary (singular) fit: see ?isSingular
#
# boundary (singular) fit: see ?isSingular
#
# boundary (singular) fit: see ?isSingular
#
# boundary (singular) fit: see ?isSingular
#
# boundary (singular) fit: see ?isSingular
#
# boundary (singular) fit: see ?isSingular
#
# boundary (singular) fit: see ?isSingular
#
# boundary (singular) fit: see ?isSingular
#
# boundary (singular) fit: see ?isSingular
#
# boundary (singular) fit: see ?isSingular
#
# boundary (singular) fit: see ?isSingular
#
# boundary (singular) fit: see ?isSingular
#
# boundary (singular) fit: see ?isSingular
#
# boundary (singular) fit: see ?isSingular
#
# boundary (singular) fit: see ?isSingular
#
# boundary (singular) fit: see ?isSingular
#
# boundary (singular) fit: see ?isSingular
#
# boundary (singular) fit: see ?isSingular
#
# boundary (singular) fit: see ?isSingular
#
# boundary (singular) fit: see ?isSingular
#
# boundary (singular) fit: see ?isSingular
#
# boundary (singular) fit: see ?isSingular
#
# boundary (singular) fit: see ?isSingular
#
# boundary (singular) fit: see ?isSingular
#
# boundary (singular) fit: see ?isSingular
#
# boundary (singular) fit: see ?isSingular
#
# boundary (singular) fit: see ?isSingular
#
# boundary (singular) fit: see ?isSingular
#
# boundary (singular) fit: see ?isSingular
#
# boundary (singular) fit: see ?isSingular
#
# boundary (singular) fit: see ?isSingular
#
# boundary (singular) fit: see ?isSingular
#
# boundary (singular) fit: see ?isSingular
#
# boundary (singular) fit: see ?isSingular
#
# boundary (singular) fit: see ?isSingular
#
# boundary (singular) fit: see ?isSingular
#
# boundary (singular) fit: see ?isSingular
#
# boundary (singular) fit: see ?isSingular
#
# boundary (singular) fit: see ?isSingular
#
# boundary (singular) fit: see ?isSingular
#
# boundary (singular) fit: see ?isSingular
#
# boundary (singular) fit: see ?isSingular
#
# boundary (singular) fit: see ?isSingular
#
# boundary (singular) fit: see ?isSingular
#
# boundary (singular) fit: see ?isSingular
#
# boundary (singular) fit: see ?isSingular
#
# boundary (singular) fit: see ?isSingular
#
# boundary (singular) fit: see ?isSingular
#
# boundary (singular) fit: see ?isSingular
#
# boundary (singular) fit: see ?isSingular
#
# boundary (singular) fit: see ?isSingular
#
# boundary (singular) fit: see ?isSingular
#
# boundary (singular) fit: see ?isSingular
#
# boundary (singular) fit: see ?isSingular
#
# boundary (singular) fit: see ?isSingular
#
# boundary (singular) fit: see ?isSingular
#
# boundary (singular) fit: see ?isSingular
#
# boundary (singular) fit: see ?isSingular
#
# boundary (singular) fit: see ?isSingular
#
# boundary (singular) fit: see ?isSingular
#
# boundary (singular) fit: see ?isSingular
#
# boundary (singular) fit: see ?isSingular
#
# boundary (singular) fit: see ?isSingular
#
# boundary (singular) fit: see ?isSingular
#
# boundary (singular) fit: see ?isSingular
#
# boundary (singular) fit: see ?isSingular
#
# boundary (singular) fit: see ?isSingular
#
# boundary (singular) fit: see ?isSingular
#
# boundary (singular) fit: see ?isSingular
#
# boundary (singular) fit: see ?isSingular
#
# boundary (singular) fit: see ?isSingular
#
# boundary (singular) fit: see ?isSingular
#
# boundary (singular) fit: see ?isSingular
#
# boundary (singular) fit: see ?isSingular
#
# boundary (singular) fit: see ?isSingular
#
# boundary (singular) fit: see ?isSingular
#
# boundary (singular) fit: see ?isSingular
#
# boundary (singular) fit: see ?isSingular
#
# boundary (singular) fit: see ?isSingular
#
# boundary (singular) fit: see ?isSingular
#
# boundary (singular) fit: see ?isSingular
#
# boundary (singular) fit: see ?isSingular
#
# boundary (singular) fit: see ?isSingular
#
# boundary (singular) fit: see ?isSingular
#
# boundary (singular) fit: see ?isSingular
#
# boundary (singular) fit: see ?isSingular
#
# boundary (singular) fit: see ?isSingular
#
# boundary (singular) fit: see ?isSingular
#
# boundary (singular) fit: see ?isSingular
#
# boundary (singular) fit: see ?isSingular
#
# boundary (singular) fit: see ?isSingular
#
# boundary (singular) fit: see ?isSingular
#
# boundary (singular) fit: see ?isSingular
#
# boundary (singular) fit: see ?isSingular
#
# boundary (singular) fit: see ?isSingular
#
# boundary (singular) fit: see ?isSingular
#
# boundary (singular) fit: see ?isSingular
#
# boundary (singular) fit: see ?isSingular
#
# boundary (singular) fit: see ?isSingular
#
# boundary (singular) fit: see ?isSingular
#
# boundary (singular) fit: see ?isSingular
#
# boundary (singular) fit: see ?isSingular
#
# boundary (singular) fit: see ?isSingular
#
# boundary (singular) fit: see ?isSingular
#
# boundary (singular) fit: see ?isSingular
#
# boundary (singular) fit: see ?isSingular
#
# boundary (singular) fit: see ?isSingular
#
# boundary (singular) fit: see ?isSingular
#
# boundary (singular) fit: see ?isSingular
#
# boundary (singular) fit: see ?isSingular
#
# boundary (singular) fit: see ?isSingular
#
# boundary (singular) fit: see ?isSingular
#
# boundary (singular) fit: see ?isSingular
#
# boundary (singular) fit: see ?isSingular
#
# boundary (singular) fit: see ?isSingular
#
# boundary (singular) fit: see ?isSingular
#
# boundary (singular) fit: see ?isSingular
#
# boundary (singular) fit: see ?isSingular
#
# boundary (singular) fit: see ?isSingular
#
# boundary (singular) fit: see ?isSingular
#
# boundary (singular) fit: see ?isSingular
#
# boundary (singular) fit: see ?isSingular
#
# boundary (singular) fit: see ?isSingular
#
# boundary (singular) fit: see ?isSingular
#
# boundary (singular) fit: see ?isSingular
#
# boundary (singular) fit: see ?isSingular
#
# boundary (singular) fit: see ?isSingular
#
# boundary (singular) fit: see ?isSingular
#
# boundary (singular) fit: see ?isSingular
#
# boundary (singular) fit: see ?isSingular
#
# boundary (singular) fit: see ?isSingular
#
# boundary (singular) fit: see ?isSingular
#
# boundary (singular) fit: see ?isSingular
#
# boundary (singular) fit: see ?isSingular
#
# boundary (singular) fit: see ?isSingular
#
# boundary (singular) fit: see ?isSingular
#
# boundary (singular) fit: see ?isSingular
#
# boundary (singular) fit: see ?isSingular
#
# boundary (singular) fit: see ?isSingular
#
# boundary (singular) fit: see ?isSingular
#
# boundary (singular) fit: see ?isSingular
#
# boundary (singular) fit: see ?isSingular
#
# boundary (singular) fit: see ?isSingular
#
# boundary (singular) fit: see ?isSingular
#
# boundary (singular) fit: see ?isSingular
#
# boundary (singular) fit: see ?isSingular
#
# boundary (singular) fit: see ?isSingular
#
# boundary (singular) fit: see ?isSingular
#
# boundary (singular) fit: see ?isSingular
#
# boundary (singular) fit: see ?isSingular
#
# boundary (singular) fit: see ?isSingular
#
# boundary (singular) fit: see ?isSingular
#
# boundary (singular) fit: see ?isSingular
#
# boundary (singular) fit: see ?isSingular
#
# boundary (singular) fit: see ?isSingular
#
# boundary (singular) fit: see ?isSingular
#
# boundary (singular) fit: see ?isSingular
#
# boundary (singular) fit: see ?isSingular
#
# boundary (singular) fit: see ?isSingular
#
# boundary (singular) fit: see ?isSingular
#
# boundary (singular) fit: see ?isSingular
#
# boundary (singular) fit: see ?isSingular
#
# boundary (singular) fit: see ?isSingular
#
# boundary (singular) fit: see ?isSingular
#
# boundary (singular) fit: see ?isSingular
#
# boundary (singular) fit: see ?isSingular
#
# boundary (singular) fit: see ?isSingular
#
# boundary (singular) fit: see ?isSingular
#
# boundary (singular) fit: see ?isSingular
#
# boundary (singular) fit: see ?isSingular
#
# boundary (singular) fit: see ?isSingular
#
# boundary (singular) fit: see ?isSingular
#
# boundary (singular) fit: see ?isSingular
#
# boundary (singular) fit: see ?isSingular
#
# boundary (singular) fit: see ?isSingular
#
# boundary (singular) fit: see ?isSingular
#
# boundary (singular) fit: see ?isSingular
#
# boundary (singular) fit: see ?isSingular
#
# boundary (singular) fit: see ?isSingular
#
# boundary (singular) fit: see ?isSingular
#
# boundary (singular) fit: see ?isSingular
#
# boundary (singular) fit: see ?isSingular
#
# boundary (singular) fit: see ?isSingular
#
# boundary (singular) fit: see ?isSingular
#
# boundary (singular) fit: see ?isSingular
#
# boundary (singular) fit: see ?isSingular
#
# boundary (singular) fit: see ?isSingular
#
# boundary (singular) fit: see ?isSingular
#
# boundary (singular) fit: see ?isSingular
#
# boundary (singular) fit: see ?isSingular
#
# boundary (singular) fit: see ?isSingular
#
# boundary (singular) fit: see ?isSingular
#
# boundary (singular) fit: see ?isSingular
#
# boundary (singular) fit: see ?isSingular
#
# boundary (singular) fit: see ?isSingular
#
# boundary (singular) fit: see ?isSingular
#
# boundary (singular) fit: see ?isSingular
#
# boundary (singular) fit: see ?isSingular
#
# boundary (singular) fit: see ?isSingular
#
# boundary (singular) fit: see ?isSingular
#
# boundary (singular) fit: see ?isSingular
#
# boundary (singular) fit: see ?isSingular
#
# boundary (singular) fit: see ?isSingular
#
# boundary (singular) fit: see ?isSingular
#
# boundary (singular) fit: see ?isSingular
#
# boundary (singular) fit: see ?isSingular
#
# boundary (singular) fit: see ?isSingular
#
# boundary (singular) fit: see ?isSingular
#
# boundary (singular) fit: see ?isSingular
#
# boundary (singular) fit: see ?isSingular
#
# boundary (singular) fit: see ?isSingular
#
# boundary (singular) fit: see ?isSingular
#
# boundary (singular) fit: see ?isSingular
#
# boundary (singular) fit: see ?isSingular
#
# boundary (singular) fit: see ?isSingular
#
# boundary (singular) fit: see ?isSingular
#
# boundary (singular) fit: see ?isSingular
#
# boundary (singular) fit: see ?isSingular
#
# boundary (singular) fit: see ?isSingular
#
# boundary (singular) fit: see ?isSingular
#
# boundary (singular) fit: see ?isSingular
#
# boundary (singular) fit: see ?isSingular
#
# boundary (singular) fit: see ?isSingular
#
# boundary (singular) fit: see ?isSingular
#
# boundary (singular) fit: see ?isSingular
#
# boundary (singular) fit: see ?isSingular
#
# boundary (singular) fit: see ?isSingular

# %%
# plot

png(file.path(dirloc, 'PVCA_norm.png'), width=800, height=400)
bp <- barplot(pvcaObj$dat,
              ylab=expression(bold("Weighted Average Proportion Variance")),
              ylim=c(0,1.1), col=c("navy"), las=2, font=4,
              main="Principal Variant Component Analysis Estimation")
axis(1,at=bp,labels=pvcaObj$label,cex.axis=1,las=2,font=4)
values <- pvcaObj$dat
new_values <- round(values,3)
text(bp,pvcaObj$dat,labels=new_values,pos=3,cex=1,font=4)
dev.off()
# Out:
# png
#   2

# %%
saveRDS(pvcaObj, file.path(dirloc, 'pvcaObj.RDS'))

# %%
# Surrogate Variable Analysis ...

# These are appended as new covariates to the existing list of covariates, and 
# we also add a step to convert them to categorical variables so as to estimate their contributions to the total variance.

# %%
# choose a biological variable that is to be used to calculate the surrogate variables
biol_var_sva <- "Etiology" 
# Perform SVA as above
pheno <- pData(inpData)
expData <- exprs(inpData) # use norm
mod  <- model.matrix(~as.factor(pheno[, biol_var_sva]), data=pheno)
mod0 <- model.matrix(~1,data=pheno)

n.sv <- 5
svobj <- svaseq(expData, mod, mod0, n.sv=n.sv)
# Out:
# Number of significant surrogate variables is:  5
# Iteration (out of 5 ):1  2  3  4  5

# %%
# reformat
srg_var <- as.data.frame(svobj$sv)     
colnames(srg_var) <- paste("sv", 1:ncol(srg_var), sep="")
pData(inpData) <- cbind(pData(inpData), srg_var)
varMetadata(inpData)[colnames(srg_var),] <- colnames(srg_var)
svobj$expSetobject <- inpData

# %%
## append to the ExpressionSet object
inpData_sv <- svobj$expSetobject

# %% [markdown]
# Computing the correlation between the surrogate variables and the covariates...
#
# We want to identify if a given surrogate variable is entirely independent of all the existing covariates or if it correlates with some technical factor, etc.

# %%
## Fit a generalized linear model for sv1
glm.sv1 <- glm(pData(inpData_sv)[,"sv1"] ~ pData(inpData_sv)[,"LibraryPool"] + 
               pData(inpData_sv)[,"TIN"] + pData(inpData_sv)[,"RIN"] +
               pData(inpData_sv)[,"DuplicationRate"] + pData(inpData_sv)[,"Etiology"] +
               pData(inpData_sv)[,"Race"] + pData(inpData_sv)[,"Sex"] + pData(inpData_sv)[,"Weight"] +
               pData(inpData_sv)[,"Height"] + pData(inpData_sv)[,"HW"] + pData(inpData_sv)[,"AFib"] +
               pData(inpData_sv)[,"VTVF"] + pData(inpData_sv)[,"Diabetes"] + pData(inpData_sv)[,"Hypertension"] +
               pData(inpData_sv)[,"LVEF"]) 
summary(glm.sv1)
# Out:
# Call:
# glm(formula = pData(inpData_sv)[, "sv1"] ~ pData(inpData_sv)[,
#     "LibraryPool"] + pData(inpData_sv)[, "TIN"] + pData(inpData_sv)[,
#     "RIN"] + pData(inpData_sv)[, "DuplicationRate"] + pData(inpData_sv)[,
#     "Etiology"] + pData(inpData_sv)[, "Race"] + pData(inpData_sv)[,
#     "Sex"] + pData(inpData_sv)[, "Weight"] + pData(inpData_sv)[,
#     "Height"] + pData(inpData_sv)[, "HW"] + pData(inpData_sv)[,
#     "AFib"] + pData(inpData_sv)[, "VTVF"] + pData(inpData_sv)[,
#     "Diabetes"] + pData(inpData_sv)[, "Hypertension"] + pData(inpData_sv)[,
#     "LVEF"])
#
# Deviance Residuals:
#       Min         1Q     Median         3Q        Max
# -0.068446  -0.011751  -0.000268   0.010948   0.091576
#
# Coefficients: (1 not defined because of singularities)
#                                                       Estimate Std. Error
# (Intercept)                                         -0.0544406  0.0121796
# pData(inpData_sv)[, "LibraryPool"]Magnet_02         -0.0213014  0.0081037
# pData(inpData_sv)[, "LibraryPool"]Magnet_03          0.0018358  0.0074480
# pData(inpData_sv)[, "LibraryPool"]Magnet_04         -0.0040595  0.0075208
# pData(inpData_sv)[, "LibraryPool"]Magnet_05          0.0122394  0.0078443
# pData(inpData_sv)[, "LibraryPool"]Magnet_06          0.0102433  0.0084503
# pData(inpData_sv)[, "LibraryPool"]Magnet_07          0.0065129  0.0074802
# pData(inpData_sv)[, "LibraryPool"]Magnet_08          0.0128071  0.0071579
# pData(inpData_sv)[, "LibraryPool"]Magnet_09         -0.0256426  0.0079350
# pData(inpData_sv)[, "LibraryPool"]Magnet_10          0.0004229  0.0077450
# pData(inpData_sv)[, "LibraryPool"]Magnet_11         -0.0161471  0.0077636
# pData(inpData_sv)[, "LibraryPool"]Magnet_12         -0.0441670  0.0075925
# pData(inpData_sv)[, "TIN"](60.6,70.1]                0.0679096  0.0051705
# pData(inpData_sv)[, "TIN"](70.1,73.3]                0.0823595  0.0058423
# pData(inpData_sv)[, "TIN"](73.3,81.5]                0.0878010  0.0059488
# pData(inpData_sv)[, "RIN"](8.1,8.5]                  0.0046178  0.0043192
# pData(inpData_sv)[, "RIN"](8.5,8.9]                  0.0067870  0.0042704
# pData(inpData_sv)[, "RIN"](8.9,10]                   0.0082079  0.0050322
# pData(inpData_sv)[, "DuplicationRate"](0.378,0.421] -0.0029964  0.0045108
# pData(inpData_sv)[, "DuplicationRate"](0.421,0.517] -0.0023253  0.0055233
# pData(inpData_sv)[, "DuplicationRate"](0.517,0.935] -0.0152526  0.0068285
# pData(inpData_sv)[, "Etiology"]DCM                  -0.0011696  0.0063048
# pData(inpData_sv)[, "Etiology"]HCM                   0.0014860  0.0071207
# pData(inpData_sv)[, "Race"]AA                        0.0037931  0.0033875
# pData(inpData_sv)[, "Sex"]F                          0.0031177  0.0050830
# pData(inpData_sv)[, "Weight"](66.2,79]              -0.0003987  0.0041544
# pData(inpData_sv)[, "Weight"](79,91]                -0.0031303  0.0045727
# pData(inpData_sv)[, "Weight"](91,267]                0.0033427  0.0049485
# pData(inpData_sv)[, "Height"](163,170]               0.0092018  0.0044619
# pData(inpData_sv)[, "Height"](170,178]               0.0071917  0.0057907
# pData(inpData_sv)[, "Height"](178,196]               0.0069474  0.0062068
# pData(inpData_sv)[, "HW"](372,448]                  -0.0041579  0.0044490
# pData(inpData_sv)[, "HW"](448,558]                  -0.0070278  0.0046239
# pData(inpData_sv)[, "HW"](558,923]                  -0.0063997  0.0048380
# pData(inpData_sv)[, "AFib"]Yes                       0.0002670  0.0036085
# pData(inpData_sv)[, "VTVF"]Yes                       0.0026320  0.0037205
# pData(inpData_sv)[, "Diabetes"]Yes                   0.0004194  0.0037053
# pData(inpData_sv)[, "Hypertension"]Yes                      NA         NA
# pData(inpData_sv)[, "LVEF"](0.15,0.2]               -0.0039887  0.0047020
# pData(inpData_sv)[, "LVEF"](0.2,0.52]               -0.0059407  0.0050952
# pData(inpData_sv)[, "LVEF"](0.52,0.8]               -0.0011782  0.0067976
#                                                     t value Pr(>|t|)
# (Intercept)                                          -4.470 1.25e-05 ***
# pData(inpData_sv)[, "LibraryPool"]Magnet_02          -2.629  0.00917 **
# pData(inpData_sv)[, "LibraryPool"]Magnet_03           0.246  0.80554
# pData(inpData_sv)[, "LibraryPool"]Magnet_04          -0.540  0.58989
# pData(inpData_sv)[, "LibraryPool"]Magnet_05           1.560  0.12011
# pData(inpData_sv)[, "LibraryPool"]Magnet_06           1.212  0.22673
# pData(inpData_sv)[, "LibraryPool"]Magnet_07           0.871  0.38487
# pData(inpData_sv)[, "LibraryPool"]Magnet_08           1.789  0.07494 .
# pData(inpData_sv)[, "LibraryPool"]Magnet_09          -3.232  0.00142 **
# pData(inpData_sv)[, "LibraryPool"]Magnet_10           0.055  0.95651
# pData(inpData_sv)[, "LibraryPool"]Magnet_11          -2.080  0.03869 *
# pData(inpData_sv)[, "LibraryPool"]Magnet_12          -5.817 2.07e-08 ***
# pData(inpData_sv)[, "TIN"](60.6,70.1]                13.134  < 2e-16 ***
# pData(inpData_sv)[, "TIN"](70.1,73.3]                14.097  < 2e-16 ***
# pData(inpData_sv)[, "TIN"](73.3,81.5]                14.760  < 2e-16 ***
# pData(inpData_sv)[, "RIN"](8.1,8.5]                   1.069  0.28617
# pData(inpData_sv)[, "RIN"](8.5,8.9]                   1.589  0.11341
# pData(inpData_sv)[, "RIN"](8.9,10]                    1.631  0.10429
# pData(inpData_sv)[, "DuplicationRate"](0.378,0.421]  -0.664  0.50721
# pData(inpData_sv)[, "DuplicationRate"](0.421,0.517]  -0.421  0.67416
# pData(inpData_sv)[, "DuplicationRate"](0.517,0.935]  -2.234  0.02650 *
# pData(inpData_sv)[, "Etiology"]DCM                   -0.186  0.85300
# pData(inpData_sv)[, "Etiology"]HCM                    0.209  0.83488
# pData(inpData_sv)[, "Race"]AA                         1.120  0.26404
# pData(inpData_sv)[, "Sex"]F                           0.613  0.54027
# pData(inpData_sv)[, "Weight"](66.2,79]               -0.096  0.92363
# pData(inpData_sv)[, "Weight"](79,91]                 -0.685  0.49433
# pData(inpData_sv)[, "Weight"](91,267]                 0.675  0.50006
# pData(inpData_sv)[, "Height"](163,170]                2.062  0.04034 *
# pData(inpData_sv)[, "Height"](170,178]                1.242  0.21557
# pData(inpData_sv)[, "Height"](178,196]                1.119  0.26422
# pData(inpData_sv)[, "HW"](372,448]                   -0.935  0.35102
# pData(inpData_sv)[, "HW"](448,558]                   -1.520  0.12996
# pData(inpData_sv)[, "HW"](558,923]                   -1.323  0.18727
# pData(inpData_sv)[, "AFib"]Yes                        0.074  0.94109
# pData(inpData_sv)[, "VTVF"]Yes                        0.707  0.48004
# pData(inpData_sv)[, "Diabetes"]Yes                    0.113  0.90997
# pData(inpData_sv)[, "Hypertension"]Yes                   NA       NA
# pData(inpData_sv)[, "LVEF"](0.15,0.2]                -0.848  0.39719
# pData(inpData_sv)[, "LVEF"](0.2,0.52]                -1.166  0.24489
# pData(inpData_sv)[, "LVEF"](0.52,0.8]                -0.173  0.86255
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# (Dispersion parameter for gaussian family taken to be 0.000497756)
#
#     Null deviance: 0.78249  on 261  degrees of freedom
# Residual deviance: 0.11050  on 222  degrees of freedom
#   (92 observations deleted due to missingness)
# AIC: -1210.5
#
# Number of Fisher Scoring iterations: 2

# %%
glm.sv2 <- glm(pData(inpData_sv)[,"sv2"] ~ pData(inpData_sv)[,"LibraryPool"] + 
               pData(inpData_sv)[,"TIN"] + pData(inpData_sv)[,"RIN"] +
               pData(inpData_sv)[,"DuplicationRate"] + pData(inpData_sv)[,"Etiology"] +
               pData(inpData_sv)[,"Race"] + pData(inpData_sv)[,"Sex"] + pData(inpData_sv)[,"Weight"] +
               pData(inpData_sv)[,"Height"] + pData(inpData_sv)[,"HW"] + pData(inpData_sv)[,"AFib"] +
               pData(inpData_sv)[,"VTVF"] + pData(inpData_sv)[,"Diabetes"] + pData(inpData_sv)[,"Hypertension"] +
               pData(inpData_sv)[,"LVEF"]) 
summary(glm.sv2)
# Out:
# Call:
# glm(formula = pData(inpData_sv)[, "sv2"] ~ pData(inpData_sv)[,
#     "LibraryPool"] + pData(inpData_sv)[, "TIN"] + pData(inpData_sv)[,
#     "RIN"] + pData(inpData_sv)[, "DuplicationRate"] + pData(inpData_sv)[,
#     "Etiology"] + pData(inpData_sv)[, "Race"] + pData(inpData_sv)[,
#     "Sex"] + pData(inpData_sv)[, "Weight"] + pData(inpData_sv)[,
#     "Height"] + pData(inpData_sv)[, "HW"] + pData(inpData_sv)[,
#     "AFib"] + pData(inpData_sv)[, "VTVF"] + pData(inpData_sv)[,
#     "Diabetes"] + pData(inpData_sv)[, "Hypertension"] + pData(inpData_sv)[,
#     "LVEF"])
#
# Deviance Residuals:
#       Min         1Q     Median         3Q        Max
# -0.144087  -0.015522   0.002433   0.015826   0.097397
#
# Coefficients: (1 not defined because of singularities)
#                                                       Estimate Std. Error
# (Intercept)                                          0.0749445  0.0174754
# pData(inpData_sv)[, "LibraryPool"]Magnet_02         -0.0167360  0.0116272
# pData(inpData_sv)[, "LibraryPool"]Magnet_03          0.0030001  0.0106864
# pData(inpData_sv)[, "LibraryPool"]Magnet_04         -0.0425959  0.0107909
# pData(inpData_sv)[, "LibraryPool"]Magnet_05          0.0219386  0.0112551
# pData(inpData_sv)[, "LibraryPool"]Magnet_06          0.0052072  0.0121245
# pData(inpData_sv)[, "LibraryPool"]Magnet_07          0.0165527  0.0107326
# pData(inpData_sv)[, "LibraryPool"]Magnet_08          0.0248293  0.0102702
# pData(inpData_sv)[, "LibraryPool"]Magnet_09         -0.0773370  0.0113852
# pData(inpData_sv)[, "LibraryPool"]Magnet_10          0.0253699  0.0111126
# pData(inpData_sv)[, "LibraryPool"]Magnet_11         -0.0594414  0.0111392
# pData(inpData_sv)[, "LibraryPool"]Magnet_12         -0.0068786  0.0108938
# pData(inpData_sv)[, "TIN"](60.6,70.1]               -0.0228174  0.0074186
# pData(inpData_sv)[, "TIN"](70.1,73.3]               -0.0438373  0.0083825
# pData(inpData_sv)[, "TIN"](73.3,81.5]               -0.0665223  0.0085353
# pData(inpData_sv)[, "RIN"](8.1,8.5]                 -0.0066271  0.0061972
# pData(inpData_sv)[, "RIN"](8.5,8.9]                  0.0126404  0.0061272
# pData(inpData_sv)[, "RIN"](8.9,10]                   0.0059018  0.0072202
# pData(inpData_sv)[, "DuplicationRate"](0.378,0.421] -0.0064193  0.0064721
# pData(inpData_sv)[, "DuplicationRate"](0.421,0.517] -0.0225989  0.0079249
# pData(inpData_sv)[, "DuplicationRate"](0.517,0.935] -0.0108566  0.0097976
# pData(inpData_sv)[, "Etiology"]DCM                  -0.0352754  0.0090462
# pData(inpData_sv)[, "Etiology"]HCM                  -0.0205044  0.0102168
# pData(inpData_sv)[, "Race"]AA                        0.0104396  0.0048604
# pData(inpData_sv)[, "Sex"]F                         -0.0037093  0.0072931
# pData(inpData_sv)[, "Weight"](66.2,79]               0.0051110  0.0059608
# pData(inpData_sv)[, "Weight"](79,91]                 0.0030688  0.0065609
# pData(inpData_sv)[, "Weight"](91,267]                0.0096655  0.0071002
# pData(inpData_sv)[, "Height"](163,170]               0.0127788  0.0064019
# pData(inpData_sv)[, "Height"](170,178]              -0.0060506  0.0083086
# pData(inpData_sv)[, "Height"](178,196]              -0.0034030  0.0089056
# pData(inpData_sv)[, "HW"](372,448]                  -0.0081659  0.0063834
# pData(inpData_sv)[, "HW"](448,558]                  -0.0149919  0.0066344
# pData(inpData_sv)[, "HW"](558,923]                  -0.0099414  0.0069416
# pData(inpData_sv)[, "AFib"]Yes                      -0.0027719  0.0051776
# pData(inpData_sv)[, "VTVF"]Yes                       0.0121227  0.0053382
# pData(inpData_sv)[, "Diabetes"]Yes                   0.0007667  0.0053164
# pData(inpData_sv)[, "Hypertension"]Yes                      NA         NA
# pData(inpData_sv)[, "LVEF"](0.15,0.2]                0.0020634  0.0067465
# pData(inpData_sv)[, "LVEF"](0.2,0.52]               -0.0163654  0.0073106
# pData(inpData_sv)[, "LVEF"](0.52,0.8]               -0.0160865  0.0097532
#                                                     t value Pr(>|t|)
# (Intercept)                                           4.289 2.68e-05 ***
# pData(inpData_sv)[, "LibraryPool"]Magnet_02          -1.439 0.151450
# pData(inpData_sv)[, "LibraryPool"]Magnet_03           0.281 0.779171
# pData(inpData_sv)[, "LibraryPool"]Magnet_04          -3.947 0.000106 ***
# pData(inpData_sv)[, "LibraryPool"]Magnet_05           1.949 0.052528 .
# pData(inpData_sv)[, "LibraryPool"]Magnet_06           0.429 0.667995
# pData(inpData_sv)[, "LibraryPool"]Magnet_07           1.542 0.124430
# pData(inpData_sv)[, "LibraryPool"]Magnet_08           2.418 0.016431 *
# pData(inpData_sv)[, "LibraryPool"]Magnet_09          -6.793 9.96e-11 ***
# pData(inpData_sv)[, "LibraryPool"]Magnet_10           2.283 0.023378 *
# pData(inpData_sv)[, "LibraryPool"]Magnet_11          -5.336 2.34e-07 ***
# pData(inpData_sv)[, "LibraryPool"]Magnet_12          -0.631 0.528411
# pData(inpData_sv)[, "TIN"](60.6,70.1]                -3.076 0.002364 **
# pData(inpData_sv)[, "TIN"](70.1,73.3]                -5.230 3.92e-07 ***
# pData(inpData_sv)[, "TIN"](73.3,81.5]                -7.794 2.49e-13 ***
# pData(inpData_sv)[, "RIN"](8.1,8.5]                  -1.069 0.286068
# pData(inpData_sv)[, "RIN"](8.5,8.9]                   2.063 0.040275 *
# pData(inpData_sv)[, "RIN"](8.9,10]                    0.817 0.414575
# pData(inpData_sv)[, "DuplicationRate"](0.378,0.421]  -0.992 0.322355
# pData(inpData_sv)[, "DuplicationRate"](0.421,0.517]  -2.852 0.004760 **
# pData(inpData_sv)[, "DuplicationRate"](0.517,0.935]  -1.108 0.269025
# pData(inpData_sv)[, "Etiology"]DCM                   -3.899 0.000128 ***
# pData(inpData_sv)[, "Etiology"]HCM                   -2.007 0.045969 *
# pData(inpData_sv)[, "Race"]AA                         2.148 0.032807 *
# pData(inpData_sv)[, "Sex"]F                          -0.509 0.611528
# pData(inpData_sv)[, "Weight"](66.2,79]                0.857 0.392131
# pData(inpData_sv)[, "Weight"](79,91]                  0.468 0.640422
# pData(inpData_sv)[, "Weight"](91,267]                 1.361 0.174797
# pData(inpData_sv)[, "Height"](163,170]                1.996 0.047147 *
# pData(inpData_sv)[, "Height"](170,178]               -0.728 0.467237
# pData(inpData_sv)[, "Height"](178,196]               -0.382 0.702741
# pData(inpData_sv)[, "HW"](372,448]                   -1.279 0.202148
# pData(inpData_sv)[, "HW"](448,558]                   -2.260 0.024808 *
# pData(inpData_sv)[, "HW"](558,923]                   -1.432 0.153508
# pData(inpData_sv)[, "AFib"]Yes                       -0.535 0.592928
# pData(inpData_sv)[, "VTVF"]Yes                        2.271 0.024109 *
# pData(inpData_sv)[, "Diabetes"]Yes                    0.144 0.885466
# pData(inpData_sv)[, "Hypertension"]Yes                   NA       NA
# pData(inpData_sv)[, "LVEF"](0.15,0.2]                 0.306 0.760009
# pData(inpData_sv)[, "LVEF"](0.2,0.52]                -2.239 0.026176 *
# pData(inpData_sv)[, "LVEF"](0.52,0.8]                -1.649 0.100489
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# (Dispersion parameter for gaussian family taken to be 0.001024713)
#
#     Null deviance: 0.73687  on 261  degrees of freedom
# Residual deviance: 0.22749  on 222  degrees of freedom
#   (92 observations deleted due to missingness)
# AIC: -1021.3
#
# Number of Fisher Scoring iterations: 2

# %%
glm.sv3 <- glm(pData(inpData_sv)[,"sv3"] ~ pData(inpData_sv)[,"LibraryPool"] + 
               pData(inpData_sv)[,"TIN"] + pData(inpData_sv)[,"RIN"] +
               pData(inpData_sv)[,"DuplicationRate"] + pData(inpData_sv)[,"Etiology"] +
               pData(inpData_sv)[,"Race"] + pData(inpData_sv)[,"Sex"] + pData(inpData_sv)[,"Weight"] +
               pData(inpData_sv)[,"Height"] + pData(inpData_sv)[,"HW"] + pData(inpData_sv)[,"AFib"] +
               pData(inpData_sv)[,"VTVF"] + pData(inpData_sv)[,"Diabetes"] + pData(inpData_sv)[,"Hypertension"] +
               pData(inpData_sv)[,"LVEF"]) 
summary(glm.sv3)
# Out:
# Call:
# glm(formula = pData(inpData_sv)[, "sv3"] ~ pData(inpData_sv)[,
#     "LibraryPool"] + pData(inpData_sv)[, "TIN"] + pData(inpData_sv)[,
#     "RIN"] + pData(inpData_sv)[, "DuplicationRate"] + pData(inpData_sv)[,
#     "Etiology"] + pData(inpData_sv)[, "Race"] + pData(inpData_sv)[,
#     "Sex"] + pData(inpData_sv)[, "Weight"] + pData(inpData_sv)[,
#     "Height"] + pData(inpData_sv)[, "HW"] + pData(inpData_sv)[,
#     "AFib"] + pData(inpData_sv)[, "VTVF"] + pData(inpData_sv)[,
#     "Diabetes"] + pData(inpData_sv)[, "Hypertension"] + pData(inpData_sv)[,
#     "LVEF"])
#
# Deviance Residuals:
#       Min         1Q     Median         3Q        Max
# -0.176157  -0.028698  -0.003764   0.022816   0.222160
#
# Coefficients: (1 not defined because of singularities)
#                                                       Estimate Std. Error
# (Intercept)                                          0.0012833  0.0273612
# pData(inpData_sv)[, "LibraryPool"]Magnet_02         -0.0625124  0.0182047
# pData(inpData_sv)[, "LibraryPool"]Magnet_03         -0.0375263  0.0167318
# pData(inpData_sv)[, "LibraryPool"]Magnet_04         -0.0260171  0.0168954
# pData(inpData_sv)[, "LibraryPool"]Magnet_05         -0.0108632  0.0176221
# pData(inpData_sv)[, "LibraryPool"]Magnet_06         -0.0096402  0.0189834
# pData(inpData_sv)[, "LibraryPool"]Magnet_07         -0.0513004  0.0168041
# pData(inpData_sv)[, "LibraryPool"]Magnet_08         -0.0183515  0.0160801
# pData(inpData_sv)[, "LibraryPool"]Magnet_09         -0.0180665  0.0178259
# pData(inpData_sv)[, "LibraryPool"]Magnet_10         -0.0192992  0.0173991
# pData(inpData_sv)[, "LibraryPool"]Magnet_11          0.0241449  0.0174408
# pData(inpData_sv)[, "LibraryPool"]Magnet_12          0.0559118  0.0170565
# pData(inpData_sv)[, "TIN"](60.6,70.1]                0.0210499  0.0116154
# pData(inpData_sv)[, "TIN"](70.1,73.3]                0.0168794  0.0131246
# pData(inpData_sv)[, "TIN"](73.3,81.5]                0.0144386  0.0133638
# pData(inpData_sv)[, "RIN"](8.1,8.5]                  0.0036272  0.0097030
# pData(inpData_sv)[, "RIN"](8.5,8.9]                 -0.0045786  0.0095933
# pData(inpData_sv)[, "RIN"](8.9,10]                   0.0068773  0.0113048
# pData(inpData_sv)[, "DuplicationRate"](0.378,0.421] -0.0082722  0.0101334
# pData(inpData_sv)[, "DuplicationRate"](0.421,0.517] -0.0225065  0.0124080
# pData(inpData_sv)[, "DuplicationRate"](0.517,0.935] -0.0441025  0.0153401
# pData(inpData_sv)[, "Etiology"]DCM                  -0.0040130  0.0141637
# pData(inpData_sv)[, "Etiology"]HCM                  -0.0151798  0.0159964
# pData(inpData_sv)[, "Race"]AA                       -0.0143211  0.0076100
# pData(inpData_sv)[, "Sex"]F                          0.0130848  0.0114188
# pData(inpData_sv)[, "Weight"](66.2,79]               0.0070013  0.0093328
# pData(inpData_sv)[, "Weight"](79,91]                 0.0076186  0.0102724
# pData(inpData_sv)[, "Weight"](91,267]               -0.0040590  0.0111167
# pData(inpData_sv)[, "Height"](163,170]              -0.0066753  0.0100235
# pData(inpData_sv)[, "Height"](170,178]              -0.0114051  0.0130088
# pData(inpData_sv)[, "Height"](178,196]               0.0021208  0.0139435
# pData(inpData_sv)[, "HW"](372,448]                   0.0155799  0.0099945
# pData(inpData_sv)[, "HW"](448,558]                   0.0089405  0.0103875
# pData(inpData_sv)[, "HW"](558,923]                   0.0221622  0.0108686
# pData(inpData_sv)[, "AFib"]Yes                       0.0102888  0.0081065
# pData(inpData_sv)[, "VTVF"]Yes                       0.0056010  0.0083580
# pData(inpData_sv)[, "Diabetes"]Yes                   0.0121057  0.0083239
# pData(inpData_sv)[, "Hypertension"]Yes                      NA         NA
# pData(inpData_sv)[, "LVEF"](0.15,0.2]                0.0031359  0.0105629
# pData(inpData_sv)[, "LVEF"](0.2,0.52]                0.0142932  0.0114463
# pData(inpData_sv)[, "LVEF"](0.52,0.8]                0.0003372  0.0152706
#                                                     t value Pr(>|t|)
# (Intercept)                                           0.047  0.96263
# pData(inpData_sv)[, "LibraryPool"]Magnet_02          -3.434  0.00071 ***
# pData(inpData_sv)[, "LibraryPool"]Magnet_03          -2.243  0.02590 *
# pData(inpData_sv)[, "LibraryPool"]Magnet_04          -1.540  0.12501
# pData(inpData_sv)[, "LibraryPool"]Magnet_05          -0.616  0.53823
# pData(inpData_sv)[, "LibraryPool"]Magnet_06          -0.508  0.61208
# pData(inpData_sv)[, "LibraryPool"]Magnet_07          -3.053  0.00254 **
# pData(inpData_sv)[, "LibraryPool"]Magnet_08          -1.141  0.25499
# pData(inpData_sv)[, "LibraryPool"]Magnet_09          -1.013  0.31193
# pData(inpData_sv)[, "LibraryPool"]Magnet_10          -1.109  0.26854
# pData(inpData_sv)[, "LibraryPool"]Magnet_11           1.384  0.16763
# pData(inpData_sv)[, "LibraryPool"]Magnet_12           3.278  0.00121 **
# pData(inpData_sv)[, "TIN"](60.6,70.1]                 1.812  0.07130 .
# pData(inpData_sv)[, "TIN"](70.1,73.3]                 1.286  0.19975
# pData(inpData_sv)[, "TIN"](73.3,81.5]                 1.080  0.28113
# pData(inpData_sv)[, "RIN"](8.1,8.5]                   0.374  0.70889
# pData(inpData_sv)[, "RIN"](8.5,8.9]                  -0.477  0.63364
# pData(inpData_sv)[, "RIN"](8.9,10]                    0.608  0.54358
# pData(inpData_sv)[, "DuplicationRate"](0.378,0.421]  -0.816  0.41519
# pData(inpData_sv)[, "DuplicationRate"](0.421,0.517]  -1.814  0.07105 .
# pData(inpData_sv)[, "DuplicationRate"](0.517,0.935]  -2.875  0.00443 **
# pData(inpData_sv)[, "Etiology"]DCM                   -0.283  0.77719
# pData(inpData_sv)[, "Etiology"]HCM                   -0.949  0.34368
# pData(inpData_sv)[, "Race"]AA                        -1.882  0.06116 .
# pData(inpData_sv)[, "Sex"]F                           1.146  0.25307
# pData(inpData_sv)[, "Weight"](66.2,79]                0.750  0.45394
# pData(inpData_sv)[, "Weight"](79,91]                  0.742  0.45908
# pData(inpData_sv)[, "Weight"](91,267]                -0.365  0.71536
# pData(inpData_sv)[, "Height"](163,170]               -0.666  0.50613
# pData(inpData_sv)[, "Height"](170,178]               -0.877  0.38158
# pData(inpData_sv)[, "Height"](178,196]                0.152  0.87924
# pData(inpData_sv)[, "HW"](372,448]                    1.559  0.12046
# pData(inpData_sv)[, "HW"](448,558]                    0.861  0.39033
# pData(inpData_sv)[, "HW"](558,923]                    2.039  0.04262 *
# pData(inpData_sv)[, "AFib"]Yes                        1.269  0.20570
# pData(inpData_sv)[, "VTVF"]Yes                        0.670  0.50347
# pData(inpData_sv)[, "Diabetes"]Yes                    1.454  0.14727
# pData(inpData_sv)[, "Hypertension"]Yes                   NA       NA
# pData(inpData_sv)[, "LVEF"](0.15,0.2]                 0.297  0.76684
# pData(inpData_sv)[, "LVEF"](0.2,0.52]                 1.249  0.21308
# pData(inpData_sv)[, "LVEF"](0.52,0.8]                 0.022  0.98240
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# (Dispersion parameter for gaussian family taken to be 0.002512012)
#
#     Null deviance: 0.85747  on 261  degrees of freedom
# Residual deviance: 0.55767  on 222  degrees of freedom
#   (92 observations deleted due to missingness)
# AIC: -786.39
#
# Number of Fisher Scoring iterations: 2

# %%
glm.sv4 <- glm(pData(inpData_sv)[,"sv4"] ~ pData(inpData_sv)[,"LibraryPool"] + 
               pData(inpData_sv)[,"TIN"] + pData(inpData_sv)[,"RIN"] +
               pData(inpData_sv)[,"DuplicationRate"] + pData(inpData_sv)[,"Etiology"] +
               pData(inpData_sv)[,"Race"] + pData(inpData_sv)[,"Sex"] + pData(inpData_sv)[,"Weight"] +
               pData(inpData_sv)[,"Height"] + pData(inpData_sv)[,"HW"] + pData(inpData_sv)[,"AFib"] +
               pData(inpData_sv)[,"VTVF"] + pData(inpData_sv)[,"Diabetes"] + pData(inpData_sv)[,"Hypertension"] +
               pData(inpData_sv)[,"LVEF"]) 
summary(glm.sv4)
# Out:
# Call:
# glm(formula = pData(inpData_sv)[, "sv4"] ~ pData(inpData_sv)[,
#     "LibraryPool"] + pData(inpData_sv)[, "TIN"] + pData(inpData_sv)[,
#     "RIN"] + pData(inpData_sv)[, "DuplicationRate"] + pData(inpData_sv)[,
#     "Etiology"] + pData(inpData_sv)[, "Race"] + pData(inpData_sv)[,
#     "Sex"] + pData(inpData_sv)[, "Weight"] + pData(inpData_sv)[,
#     "Height"] + pData(inpData_sv)[, "HW"] + pData(inpData_sv)[,
#     "AFib"] + pData(inpData_sv)[, "VTVF"] + pData(inpData_sv)[,
#     "Diabetes"] + pData(inpData_sv)[, "Hypertension"] + pData(inpData_sv)[,
#     "LVEF"])
#
# Deviance Residuals:
#       Min         1Q     Median         3Q        Max
# -0.124318  -0.024523  -0.000557   0.021854   0.143812
#
# Coefficients: (1 not defined because of singularities)
#                                                       Estimate Std. Error
# (Intercept)                                          0.0345176  0.0230448
# pData(inpData_sv)[, "LibraryPool"]Magnet_02          0.0770188  0.0153328
# pData(inpData_sv)[, "LibraryPool"]Magnet_03         -0.0424131  0.0140922
# pData(inpData_sv)[, "LibraryPool"]Magnet_04         -0.0069284  0.0142300
# pData(inpData_sv)[, "LibraryPool"]Magnet_05         -0.0141081  0.0148421
# pData(inpData_sv)[, "LibraryPool"]Magnet_06         -0.0484767  0.0159886
# pData(inpData_sv)[, "LibraryPool"]Magnet_07         -0.0437140  0.0141532
# pData(inpData_sv)[, "LibraryPool"]Magnet_08         -0.0238010  0.0135434
# pData(inpData_sv)[, "LibraryPool"]Magnet_09         -0.0477815  0.0150138
# pData(inpData_sv)[, "LibraryPool"]Magnet_10         -0.0220640  0.0146543
# pData(inpData_sv)[, "LibraryPool"]Magnet_11         -0.0430187  0.0146894
# pData(inpData_sv)[, "LibraryPool"]Magnet_12         -0.0552889  0.0143657
# pData(inpData_sv)[, "TIN"](60.6,70.1]                0.0122397  0.0097830
# pData(inpData_sv)[, "TIN"](70.1,73.3]                0.0119896  0.0110541
# pData(inpData_sv)[, "TIN"](73.3,81.5]                0.0269405  0.0112556
# pData(inpData_sv)[, "RIN"](8.1,8.5]                 -0.0181196  0.0081723
# pData(inpData_sv)[, "RIN"](8.5,8.9]                 -0.0178397  0.0080799
# pData(inpData_sv)[, "RIN"](8.9,10]                  -0.0258800  0.0095214
# pData(inpData_sv)[, "DuplicationRate"](0.378,0.421] -0.0008775  0.0085348
# pData(inpData_sv)[, "DuplicationRate"](0.421,0.517] -0.0176817  0.0104506
# pData(inpData_sv)[, "DuplicationRate"](0.517,0.935] -0.0046338  0.0129201
# pData(inpData_sv)[, "Etiology"]DCM                  -0.0148139  0.0119293
# pData(inpData_sv)[, "Etiology"]HCM                  -0.0214009  0.0134729
# pData(inpData_sv)[, "Race"]AA                        0.0086982  0.0064095
# pData(inpData_sv)[, "Sex"]F                          0.0042469  0.0096174
# pData(inpData_sv)[, "Weight"](66.2,79]              -0.0051311  0.0078605
# pData(inpData_sv)[, "Weight"](79,91]                 0.0057986  0.0086518
# pData(inpData_sv)[, "Weight"](91,267]                0.0049899  0.0093630
# pData(inpData_sv)[, "Height"](163,170]              -0.0160202  0.0084422
# pData(inpData_sv)[, "Height"](170,178]              -0.0135502  0.0109565
# pData(inpData_sv)[, "Height"](178,196]              -0.0118346  0.0117438
# pData(inpData_sv)[, "HW"](372,448]                   0.0099415  0.0084178
# pData(inpData_sv)[, "HW"](448,558]                   0.0155617  0.0087488
# pData(inpData_sv)[, "HW"](558,923]                   0.0152792  0.0091540
# pData(inpData_sv)[, "AFib"]Yes                      -0.0055708  0.0068277
# pData(inpData_sv)[, "VTVF"]Yes                       0.0094056  0.0070395
# pData(inpData_sv)[, "Diabetes"]Yes                  -0.0173719  0.0070108
# pData(inpData_sv)[, "Hypertension"]Yes                      NA         NA
# pData(inpData_sv)[, "LVEF"](0.15,0.2]                0.0059538  0.0088966
# pData(inpData_sv)[, "LVEF"](0.2,0.52]                0.0081862  0.0096405
# pData(inpData_sv)[, "LVEF"](0.52,0.8]                0.0055024  0.0128616
#                                                     t value Pr(>|t|)
# (Intercept)                                           1.498 0.135593
# pData(inpData_sv)[, "LibraryPool"]Magnet_02           5.023 1.04e-06 ***
# pData(inpData_sv)[, "LibraryPool"]Magnet_03          -3.010 0.002918 **
# pData(inpData_sv)[, "LibraryPool"]Magnet_04          -0.487 0.626821
# pData(inpData_sv)[, "LibraryPool"]Magnet_05          -0.951 0.342868
# pData(inpData_sv)[, "LibraryPool"]Magnet_06          -3.032 0.002719 **
# pData(inpData_sv)[, "LibraryPool"]Magnet_07          -3.089 0.002267 **
# pData(inpData_sv)[, "LibraryPool"]Magnet_08          -1.757 0.080230 .
# pData(inpData_sv)[, "LibraryPool"]Magnet_09          -3.183 0.001669 **
# pData(inpData_sv)[, "LibraryPool"]Magnet_10          -1.506 0.133582
# pData(inpData_sv)[, "LibraryPool"]Magnet_11          -2.929 0.003760 **
# pData(inpData_sv)[, "LibraryPool"]Magnet_12          -3.849 0.000155 ***
# pData(inpData_sv)[, "TIN"](60.6,70.1]                 1.251 0.212206
# pData(inpData_sv)[, "TIN"](70.1,73.3]                 1.085 0.279260
# pData(inpData_sv)[, "TIN"](73.3,81.5]                 2.394 0.017519 *
# pData(inpData_sv)[, "RIN"](8.1,8.5]                  -2.217 0.027623 *
# pData(inpData_sv)[, "RIN"](8.5,8.9]                  -2.208 0.028273 *
# pData(inpData_sv)[, "RIN"](8.9,10]                   -2.718 0.007084 **
# pData(inpData_sv)[, "DuplicationRate"](0.378,0.421]  -0.103 0.918203
# pData(inpData_sv)[, "DuplicationRate"](0.421,0.517]  -1.692 0.092062 .
# pData(inpData_sv)[, "DuplicationRate"](0.517,0.935]  -0.359 0.720197
# pData(inpData_sv)[, "Etiology"]DCM                   -1.242 0.215617
# pData(inpData_sv)[, "Etiology"]HCM                   -1.588 0.113610
# pData(inpData_sv)[, "Race"]AA                         1.357 0.176131
# pData(inpData_sv)[, "Sex"]F                           0.442 0.659219
# pData(inpData_sv)[, "Weight"](66.2,79]               -0.653 0.514583
# pData(inpData_sv)[, "Weight"](79,91]                  0.670 0.503415
# pData(inpData_sv)[, "Weight"](91,267]                 0.533 0.594611
# pData(inpData_sv)[, "Height"](163,170]               -1.898 0.059044 .
# pData(inpData_sv)[, "Height"](170,178]               -1.237 0.217495
# pData(inpData_sv)[, "Height"](178,196]               -1.008 0.314679
# pData(inpData_sv)[, "HW"](372,448]                    1.181 0.238862
# pData(inpData_sv)[, "HW"](448,558]                    1.779 0.076652 .
# pData(inpData_sv)[, "HW"](558,923]                    1.669 0.096501 .
# pData(inpData_sv)[, "AFib"]Yes                       -0.816 0.415418
# pData(inpData_sv)[, "VTVF"]Yes                        1.336 0.182880
# pData(inpData_sv)[, "Diabetes"]Yes                   -2.478 0.013962 *
# pData(inpData_sv)[, "Hypertension"]Yes                   NA       NA
# pData(inpData_sv)[, "LVEF"](0.15,0.2]                 0.669 0.504050
# pData(inpData_sv)[, "LVEF"](0.2,0.52]                 0.849 0.396716
# pData(inpData_sv)[, "LVEF"](0.52,0.8]                 0.428 0.669201
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# (Dispersion parameter for gaussian family taken to be 0.001781954)
#
#     Null deviance: 0.77750  on 261  degrees of freedom
# Residual deviance: 0.39559  on 222  degrees of freedom
#   (92 observations deleted due to missingness)
# AIC: -876.35
#
# Number of Fisher Scoring iterations: 2

# %%
glm.sv5 <- glm(pData(inpData_sv)[,"sv5"] ~ pData(inpData_sv)[,"LibraryPool"] + 
               pData(inpData_sv)[,"TIN"] + pData(inpData_sv)[,"RIN"] +
               pData(inpData_sv)[,"DuplicationRate"] + pData(inpData_sv)[,"Etiology"] +
               pData(inpData_sv)[,"Race"] + pData(inpData_sv)[,"Sex"] + pData(inpData_sv)[,"Weight"] +
               pData(inpData_sv)[,"Height"] + pData(inpData_sv)[,"HW"] + pData(inpData_sv)[,"AFib"] +
               pData(inpData_sv)[,"VTVF"] + pData(inpData_sv)[,"Diabetes"] + pData(inpData_sv)[,"Hypertension"] +
               pData(inpData_sv)[,"LVEF"]) 
summary(glm.sv5)
# Out:
# Call:
# glm(formula = pData(inpData_sv)[, "sv5"] ~ pData(inpData_sv)[,
#     "LibraryPool"] + pData(inpData_sv)[, "TIN"] + pData(inpData_sv)[,
#     "RIN"] + pData(inpData_sv)[, "DuplicationRate"] + pData(inpData_sv)[,
#     "Etiology"] + pData(inpData_sv)[, "Race"] + pData(inpData_sv)[,
#     "Sex"] + pData(inpData_sv)[, "Weight"] + pData(inpData_sv)[,
#     "Height"] + pData(inpData_sv)[, "HW"] + pData(inpData_sv)[,
#     "AFib"] + pData(inpData_sv)[, "VTVF"] + pData(inpData_sv)[,
#     "Diabetes"] + pData(inpData_sv)[, "Hypertension"] + pData(inpData_sv)[,
#     "LVEF"])
#
# Deviance Residuals:
#       Min         1Q     Median         3Q        Max
# -0.283466  -0.023588   0.002147   0.025983   0.140069
#
# Coefficients: (1 not defined because of singularities)
#                                                       Estimate Std. Error
# (Intercept)                                          0.0110040  0.0274284
# pData(inpData_sv)[, "LibraryPool"]Magnet_02          0.0073946  0.0182494
# pData(inpData_sv)[, "LibraryPool"]Magnet_03         -0.0035256  0.0167729
# pData(inpData_sv)[, "LibraryPool"]Magnet_04         -0.0087480  0.0169369
# pData(inpData_sv)[, "LibraryPool"]Magnet_05         -0.0090834  0.0176654
# pData(inpData_sv)[, "LibraryPool"]Magnet_06         -0.0103942  0.0190300
# pData(inpData_sv)[, "LibraryPool"]Magnet_07         -0.0052256  0.0168454
# pData(inpData_sv)[, "LibraryPool"]Magnet_08         -0.0156289  0.0161196
# pData(inpData_sv)[, "LibraryPool"]Magnet_09         -0.0772024  0.0178697
# pData(inpData_sv)[, "LibraryPool"]Magnet_10         -0.0284588  0.0174418
# pData(inpData_sv)[, "LibraryPool"]Magnet_11          0.0140046  0.0174836
# pData(inpData_sv)[, "LibraryPool"]Magnet_12          0.0038068  0.0170984
# pData(inpData_sv)[, "TIN"](60.6,70.1]               -0.0034439  0.0116439
# pData(inpData_sv)[, "TIN"](70.1,73.3]                0.0217765  0.0131568
# pData(inpData_sv)[, "TIN"](73.3,81.5]                0.0239190  0.0133966
# pData(inpData_sv)[, "RIN"](8.1,8.5]                 -0.0077522  0.0097268
# pData(inpData_sv)[, "RIN"](8.5,8.9]                 -0.0147513  0.0096169
# pData(inpData_sv)[, "RIN"](8.9,10]                  -0.0147546  0.0113325
# pData(inpData_sv)[, "DuplicationRate"](0.378,0.421] -0.0102984  0.0101583
# pData(inpData_sv)[, "DuplicationRate"](0.421,0.517] -0.0104641  0.0124385
# pData(inpData_sv)[, "DuplicationRate"](0.517,0.935] -0.0128092  0.0153778
# pData(inpData_sv)[, "Etiology"]DCM                   0.0163560  0.0141985
# pData(inpData_sv)[, "Etiology"]HCM                   0.0341647  0.0160357
# pData(inpData_sv)[, "Race"]AA                        0.0011668  0.0076287
# pData(inpData_sv)[, "Sex"]F                         -0.0156325  0.0114468
# pData(inpData_sv)[, "Weight"](66.2,79]               0.0073708  0.0093557
# pData(inpData_sv)[, "Weight"](79,91]                 0.0033091  0.0102976
# pData(inpData_sv)[, "Weight"](91,267]                0.0129066  0.0111440
# pData(inpData_sv)[, "Height"](163,170]               0.0008332  0.0100481
# pData(inpData_sv)[, "Height"](170,178]              -0.0083189  0.0130407
# pData(inpData_sv)[, "Height"](178,196]              -0.0072504  0.0139777
# pData(inpData_sv)[, "HW"](372,448]                   0.0151088  0.0100191
# pData(inpData_sv)[, "HW"](448,558]                  -0.0063403  0.0104130
# pData(inpData_sv)[, "HW"](558,923]                   0.0083815  0.0108952
# pData(inpData_sv)[, "AFib"]Yes                      -0.0094609  0.0081264
# pData(inpData_sv)[, "VTVF"]Yes                      -0.0087933  0.0083785
# pData(inpData_sv)[, "Diabetes"]Yes                   0.0100664  0.0083444
# pData(inpData_sv)[, "Hypertension"]Yes                      NA         NA
# pData(inpData_sv)[, "LVEF"](0.15,0.2]                0.0121519  0.0105889
# pData(inpData_sv)[, "LVEF"](0.2,0.52]               -0.0147806  0.0114744
# pData(inpData_sv)[, "LVEF"](0.52,0.8]               -0.0036427  0.0153081
#                                                     t value Pr(>|t|)
# (Intercept)                                           0.401   0.6887
# pData(inpData_sv)[, "LibraryPool"]Magnet_02           0.405   0.6857
# pData(inpData_sv)[, "LibraryPool"]Magnet_03          -0.210   0.8337
# pData(inpData_sv)[, "LibraryPool"]Magnet_04          -0.517   0.6060
# pData(inpData_sv)[, "LibraryPool"]Magnet_05          -0.514   0.6076
# pData(inpData_sv)[, "LibraryPool"]Magnet_06          -0.546   0.5855
# pData(inpData_sv)[, "LibraryPool"]Magnet_07          -0.310   0.7567
# pData(inpData_sv)[, "LibraryPool"]Magnet_08          -0.970   0.3333
# pData(inpData_sv)[, "LibraryPool"]Magnet_09          -4.320 2.35e-05 ***
# pData(inpData_sv)[, "LibraryPool"]Magnet_10          -1.632   0.1042
# pData(inpData_sv)[, "LibraryPool"]Magnet_11           0.801   0.4240
# pData(inpData_sv)[, "LibraryPool"]Magnet_12           0.223   0.8240
# pData(inpData_sv)[, "TIN"](60.6,70.1]                -0.296   0.7677
# pData(inpData_sv)[, "TIN"](70.1,73.3]                 1.655   0.0993 .
# pData(inpData_sv)[, "TIN"](73.3,81.5]                 1.785   0.0756 .
# pData(inpData_sv)[, "RIN"](8.1,8.5]                  -0.797   0.4263
# pData(inpData_sv)[, "RIN"](8.5,8.9]                  -1.534   0.1265
# pData(inpData_sv)[, "RIN"](8.9,10]                   -1.302   0.1943
# pData(inpData_sv)[, "DuplicationRate"](0.378,0.421]  -1.014   0.3118
# pData(inpData_sv)[, "DuplicationRate"](0.421,0.517]  -0.841   0.4011
# pData(inpData_sv)[, "DuplicationRate"](0.517,0.935]  -0.833   0.4058
# pData(inpData_sv)[, "Etiology"]DCM                    1.152   0.2506
# pData(inpData_sv)[, "Etiology"]HCM                    2.131   0.0342 *
# pData(inpData_sv)[, "Race"]AA                         0.153   0.8786
# pData(inpData_sv)[, "Sex"]F                          -1.366   0.1734
# pData(inpData_sv)[, "Weight"](66.2,79]                0.788   0.4316
# pData(inpData_sv)[, "Weight"](79,91]                  0.321   0.7482
# pData(inpData_sv)[, "Weight"](91,267]                 1.158   0.2480
# pData(inpData_sv)[, "Height"](163,170]                0.083   0.9340
# pData(inpData_sv)[, "Height"](170,178]               -0.638   0.5242
# pData(inpData_sv)[, "Height"](178,196]               -0.519   0.6045
# pData(inpData_sv)[, "HW"](372,448]                    1.508   0.1330
# pData(inpData_sv)[, "HW"](448,558]                   -0.609   0.5432
# pData(inpData_sv)[, "HW"](558,923]                    0.769   0.4425
# pData(inpData_sv)[, "AFib"]Yes                       -1.164   0.2456
# pData(inpData_sv)[, "VTVF"]Yes                       -1.050   0.2951
# pData(inpData_sv)[, "Diabetes"]Yes                    1.206   0.2290
# pData(inpData_sv)[, "Hypertension"]Yes                   NA       NA
# pData(inpData_sv)[, "LVEF"](0.15,0.2]                 1.148   0.2524
# pData(inpData_sv)[, "LVEF"](0.2,0.52]                -1.288   0.1990
# pData(inpData_sv)[, "LVEF"](0.52,0.8]                -0.238   0.8121
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# (Dispersion parameter for gaussian family taken to be 0.002524363)
#
#     Null deviance: 0.75948  on 261  degrees of freedom
# Residual deviance: 0.56041  on 222  degrees of freedom
#   (92 observations deleted due to missingness)
# AIC: -785.1
#
# Number of Fisher Scoring iterations: 2

# %%
# Principal Variance Component Analysis of the raw data with the surrogate variables included as covariates

# %%
# discretize the continuous surrogate variables 
var_names <- c("sv1", "sv2", "sv3", "sv4", "sv5") 
pData(inpData_sv) <- conTocat(pData(inpData_sv), var_names) 
## Include the surrogate variables as covariates in addition to others
cvrts_eff_var <- c(cvrts_eff_var, "sv1_cat", "sv2_cat", "sv3_cat", "sv4_cat", "sv5_cat")
## again set the PVCA Threshold to explain 75% of the expression variation
pct_thrsh <- 0.75 
## Perform PVCA
pvcaObj_sva <- pvcaBatchAssess(inpData_sv, cvrts_eff_var, pct_thrsh)
# Out:
# boundary (singular) fit: see ?isSingular
#
# boundary (singular) fit: see ?isSingular
#
# boundary (singular) fit: see ?isSingular
#
# boundary (singular) fit: see ?isSingular
#
# boundary (singular) fit: see ?isSingular
#
# boundary (singular) fit: see ?isSingular
#
# boundary (singular) fit: see ?isSingular
#
# boundary (singular) fit: see ?isSingular
#
# boundary (singular) fit: see ?isSingular
#
# boundary (singular) fit: see ?isSingular
#
# boundary (singular) fit: see ?isSingular
#
# boundary (singular) fit: see ?isSingular
#
# boundary (singular) fit: see ?isSingular
#
# boundary (singular) fit: see ?isSingular
#
# boundary (singular) fit: see ?isSingular
#
# boundary (singular) fit: see ?isSingular
#
# boundary (singular) fit: see ?isSingular
#
# boundary (singular) fit: see ?isSingular
#
# boundary (singular) fit: see ?isSingular
#
# boundary (singular) fit: see ?isSingular
#
# boundary (singular) fit: see ?isSingular
#
# boundary (singular) fit: see ?isSingular
#
# boundary (singular) fit: see ?isSingular
#
# boundary (singular) fit: see ?isSingular
#
# boundary (singular) fit: see ?isSingular
#
# boundary (singular) fit: see ?isSingular
#
# boundary (singular) fit: see ?isSingular
#
# boundary (singular) fit: see ?isSingular
#
# boundary (singular) fit: see ?isSingular
#
# boundary (singular) fit: see ?isSingular
#
# boundary (singular) fit: see ?isSingular
#
# boundary (singular) fit: see ?isSingular
#
# boundary (singular) fit: see ?isSingular
#
# boundary (singular) fit: see ?isSingular
#
# boundary (singular) fit: see ?isSingular
#
# boundary (singular) fit: see ?isSingular
#
# boundary (singular) fit: see ?isSingular
#
# boundary (singular) fit: see ?isSingular
#
# boundary (singular) fit: see ?isSingular
#
# boundary (singular) fit: see ?isSingular
#
# boundary (singular) fit: see ?isSingular
#
# boundary (singular) fit: see ?isSingular
#
# boundary (singular) fit: see ?isSingular
#
# boundary (singular) fit: see ?isSingular
#
# boundary (singular) fit: see ?isSingular
#
# boundary (singular) fit: see ?isSingular
#
# boundary (singular) fit: see ?isSingular
#
# boundary (singular) fit: see ?isSingular
#
# boundary (singular) fit: see ?isSingular
#
# boundary (singular) fit: see ?isSingular
#
# boundary (singular) fit: see ?isSingular
#
# boundary (singular) fit: see ?isSingular
#
# boundary (singular) fit: see ?isSingular
#
# boundary (singular) fit: see ?isSingular
#
# boundary (singular) fit: see ?isSingular
#
# boundary (singular) fit: see ?isSingular
#
# boundary (singular) fit: see ?isSingular
#
# boundary (singular) fit: see ?isSingular
#
# boundary (singular) fit: see ?isSingular
#
# boundary (singular) fit: see ?isSingular
#
# boundary (singular) fit: see ?isSingular
#
# boundary (singular) fit: see ?isSingular
#
# boundary (singular) fit: see ?isSingular
#
# boundary (singular) fit: see ?isSingular
#
# boundary (singular) fit: see ?isSingular
#
# boundary (singular) fit: see ?isSingular
#
# boundary (singular) fit: see ?isSingular
#
# boundary (singular) fit: see ?isSingular
#
# boundary (singular) fit: see ?isSingular
#
# boundary (singular) fit: see ?isSingular
#
# boundary (singular) fit: see ?isSingular
#
# boundary (singular) fit: see ?isSingular
#
# boundary (singular) fit: see ?isSingular
#
# boundary (singular) fit: see ?isSingular
#
# boundary (singular) fit: see ?isSingular
#
# boundary (singular) fit: see ?isSingular
#
# boundary (singular) fit: see ?isSingular
#
# boundary (singular) fit: see ?isSingular
#
# boundary (singular) fit: see ?isSingular
#
# boundary (singular) fit: see ?isSingular
#
# boundary (singular) fit: see ?isSingular
#
# boundary (singular) fit: see ?isSingular
#
# boundary (singular) fit: see ?isSingular
#
# boundary (singular) fit: see ?isSingular
#
# boundary (singular) fit: see ?isSingular
#
# boundary (singular) fit: see ?isSingular
#
# boundary (singular) fit: see ?isSingular
#
# boundary (singular) fit: see ?isSingular
#
# boundary (singular) fit: see ?isSingular
#
# boundary (singular) fit: see ?isSingular
#
# boundary (singular) fit: see ?isSingular
#
# boundary (singular) fit: see ?isSingular
#
# boundary (singular) fit: see ?isSingular
#
# boundary (singular) fit: see ?isSingular
#
# boundary (singular) fit: see ?isSingular
#
# boundary (singular) fit: see ?isSingular
#
# boundary (singular) fit: see ?isSingular
#
# boundary (singular) fit: see ?isSingular
#
# boundary (singular) fit: see ?isSingular
#
# boundary (singular) fit: see ?isSingular
#
# boundary (singular) fit: see ?isSingular
#
# boundary (singular) fit: see ?isSingular
#
# boundary (singular) fit: see ?isSingular
#
# boundary (singular) fit: see ?isSingular
#
# boundary (singular) fit: see ?isSingular
#
# boundary (singular) fit: see ?isSingular
#
# boundary (singular) fit: see ?isSingular
#
# boundary (singular) fit: see ?isSingular
#
# boundary (singular) fit: see ?isSingular
#
# boundary (singular) fit: see ?isSingular
#
# boundary (singular) fit: see ?isSingular
#
# boundary (singular) fit: see ?isSingular
#
# boundary (singular) fit: see ?isSingular
#
# boundary (singular) fit: see ?isSingular
#
# boundary (singular) fit: see ?isSingular
#
# boundary (singular) fit: see ?isSingular
#
# boundary (singular) fit: see ?isSingular
#
# boundary (singular) fit: see ?isSingular
#
# boundary (singular) fit: see ?isSingular
#
# boundary (singular) fit: see ?isSingular
#
# boundary (singular) fit: see ?isSingular
#
# boundary (singular) fit: see ?isSingular
#
# boundary (singular) fit: see ?isSingular
#
# boundary (singular) fit: see ?isSingular
#
# boundary (singular) fit: see ?isSingular
#
# boundary (singular) fit: see ?isSingular
#
# boundary (singular) fit: see ?isSingular
#
# boundary (singular) fit: see ?isSingular
#
# boundary (singular) fit: see ?isSingular
#
# boundary (singular) fit: see ?isSingular
#
# boundary (singular) fit: see ?isSingular
#
# boundary (singular) fit: see ?isSingular
#
# boundary (singular) fit: see ?isSingular
#
# boundary (singular) fit: see ?isSingular
#
# boundary (singular) fit: see ?isSingular
#
# boundary (singular) fit: see ?isSingular
#
# boundary (singular) fit: see ?isSingular
#
# boundary (singular) fit: see ?isSingular
#
# boundary (singular) fit: see ?isSingular
#
# boundary (singular) fit: see ?isSingular
#
# boundary (singular) fit: see ?isSingular
#
# boundary (singular) fit: see ?isSingular
#
# boundary (singular) fit: see ?isSingular
#
# boundary (singular) fit: see ?isSingular
#
# boundary (singular) fit: see ?isSingular
#
# boundary (singular) fit: see ?isSingular
#
# boundary (singular) fit: see ?isSingular
#
# boundary (singular) fit: see ?isSingular
#
# boundary (singular) fit: see ?isSingular
#
# boundary (singular) fit: see ?isSingular
#
# boundary (singular) fit: see ?isSingular
#
# boundary (singular) fit: see ?isSingular
#
# boundary (singular) fit: see ?isSingular
#
# boundary (singular) fit: see ?isSingular
#
# boundary (singular) fit: see ?isSingular
#
# boundary (singular) fit: see ?isSingular
#
# boundary (singular) fit: see ?isSingular
#
# boundary (singular) fit: see ?isSingular
#
# boundary (singular) fit: see ?isSingular
#
# boundary (singular) fit: see ?isSingular
#
# boundary (singular) fit: see ?isSingular
#
# boundary (singular) fit: see ?isSingular
#
# boundary (singular) fit: see ?isSingular
#
# boundary (singular) fit: see ?isSingular
#
# boundary (singular) fit: see ?isSingular
#
# boundary (singular) fit: see ?isSingular
#
# boundary (singular) fit: see ?isSingular
#
# boundary (singular) fit: see ?isSingular
#
# boundary (singular) fit: see ?isSingular
#
# boundary (singular) fit: see ?isSingular
#
# boundary (singular) fit: see ?isSingular
#
# boundary (singular) fit: see ?isSingular
#
# boundary (singular) fit: see ?isSingular
#
# boundary (singular) fit: see ?isSingular
#
# boundary (singular) fit: see ?isSingular
#
# boundary (singular) fit: see ?isSingular
#
# boundary (singular) fit: see ?isSingular
#
# boundary (singular) fit: see ?isSingular
#
# boundary (singular) fit: see ?isSingular
#
# boundary (singular) fit: see ?isSingular
#
# boundary (singular) fit: see ?isSingular
#
# boundary (singular) fit: see ?isSingular
#
# boundary (singular) fit: see ?isSingular
#
# boundary (singular) fit: see ?isSingular
#
# boundary (singular) fit: see ?isSingular
#
# boundary (singular) fit: see ?isSingular
#
# boundary (singular) fit: see ?isSingular
#
# boundary (singular) fit: see ?isSingular
#
# boundary (singular) fit: see ?isSingular
#
# boundary (singular) fit: see ?isSingular
#
# boundary (singular) fit: see ?isSingular
#
# boundary (singular) fit: see ?isSingular
#
# boundary (singular) fit: see ?isSingular
#
# boundary (singular) fit: see ?isSingular
#
# boundary (singular) fit: see ?isSingular
#
# boundary (singular) fit: see ?isSingular
#
# boundary (singular) fit: see ?isSingular
#
# boundary (singular) fit: see ?isSingular
#
# boundary (singular) fit: see ?isSingular
#
# boundary (singular) fit: see ?isSingular
#
# boundary (singular) fit: see ?isSingular
#
# boundary (singular) fit: see ?isSingular
#
# boundary (singular) fit: see ?isSingular
#
# boundary (singular) fit: see ?isSingular
#
# boundary (singular) fit: see ?isSingular
#
# boundary (singular) fit: see ?isSingular
#
# boundary (singular) fit: see ?isSingular
#
# boundary (singular) fit: see ?isSingular
#
# boundary (singular) fit: see ?isSingular
#
# boundary (singular) fit: see ?isSingular
#
# boundary (singular) fit: see ?isSingular
#
# boundary (singular) fit: see ?isSingular
#
# boundary (singular) fit: see ?isSingular
#
# boundary (singular) fit: see ?isSingular
#
# boundary (singular) fit: see ?isSingular
#
# boundary (singular) fit: see ?isSingular
#
# boundary (singular) fit: see ?isSingular
#
# boundary (singular) fit: see ?isSingular
#
# boundary (singular) fit: see ?isSingular
#
# boundary (singular) fit: see ?isSingular
#
# boundary (singular) fit: see ?isSingular
#
# boundary (singular) fit: see ?isSingular
#
# boundary (singular) fit: see ?isSingular
#
# boundary (singular) fit: see ?isSingular
#
# boundary (singular) fit: see ?isSingular
#
# boundary (singular) fit: see ?isSingular
#
# boundary (singular) fit: see ?isSingular
#
# boundary (singular) fit: see ?isSingular

# %%
png(file.path(dirloc, 'PVCA_sva.png'), width=800, height=400)
bp <- barplot(pvcaObj_sva$dat,
              ylab=expression(bold("Weighted Average Proportion Variance")),
              ylim=c(0,1.1), col=c("navy"), las=2, font=4,
              main="Principal Variant Component Analysis Estimation")
axis(1,at=bp,labels=pvcaObj_sva$label,cex.axis=1,las=2,font=4)
values <- pvcaObj_sva$dat
new_values <- round(values,3)
text(bp,pvcaObj_sva$dat,labels=new_values,pos=3,cex=1,font=4)
dev.off()
# Out:
# png
#   2

# %%
# For comparison, remove TIN and LibraryPool to see how much of it the surrogate variables capture
pvcaObj_sva2 <- pvcaBatchAssess(inpData_sv, cvrts_eff_var[-which(cvrts_eff_var %in% c('LibraryPool', 'TIN'))], pct_thrsh)
# Out:
# boundary (singular) fit: see ?isSingular
#
# boundary (singular) fit: see ?isSingular
#
# boundary (singular) fit: see ?isSingular
#
# boundary (singular) fit: see ?isSingular
#
# boundary (singular) fit: see ?isSingular
#
# boundary (singular) fit: see ?isSingular
#
# boundary (singular) fit: see ?isSingular
#
# boundary (singular) fit: see ?isSingular
#
# boundary (singular) fit: see ?isSingular
#
# boundary (singular) fit: see ?isSingular
#
# boundary (singular) fit: see ?isSingular
#
# boundary (singular) fit: see ?isSingular
#
# boundary (singular) fit: see ?isSingular
#
# boundary (singular) fit: see ?isSingular
#
# boundary (singular) fit: see ?isSingular
#
# boundary (singular) fit: see ?isSingular
#
# boundary (singular) fit: see ?isSingular
#
# boundary (singular) fit: see ?isSingular
#
# boundary (singular) fit: see ?isSingular
#
# boundary (singular) fit: see ?isSingular
#
# boundary (singular) fit: see ?isSingular
#
# boundary (singular) fit: see ?isSingular
#
# boundary (singular) fit: see ?isSingular
#
# boundary (singular) fit: see ?isSingular
#
# boundary (singular) fit: see ?isSingular
#
# boundary (singular) fit: see ?isSingular
#
# boundary (singular) fit: see ?isSingular
#
# boundary (singular) fit: see ?isSingular
#
# boundary (singular) fit: see ?isSingular
#
# boundary (singular) fit: see ?isSingular
#
# boundary (singular) fit: see ?isSingular
#
# boundary (singular) fit: see ?isSingular
#
# boundary (singular) fit: see ?isSingular
#
# boundary (singular) fit: see ?isSingular
#
# boundary (singular) fit: see ?isSingular
#
# boundary (singular) fit: see ?isSingular
#
# boundary (singular) fit: see ?isSingular
#
# boundary (singular) fit: see ?isSingular
#
# boundary (singular) fit: see ?isSingular
#
# boundary (singular) fit: see ?isSingular
#
# boundary (singular) fit: see ?isSingular
#
# boundary (singular) fit: see ?isSingular
#
# boundary (singular) fit: see ?isSingular
#
# boundary (singular) fit: see ?isSingular
#
# boundary (singular) fit: see ?isSingular
#
# boundary (singular) fit: see ?isSingular
#
# boundary (singular) fit: see ?isSingular
#
# boundary (singular) fit: see ?isSingular
#
# boundary (singular) fit: see ?isSingular
#
# boundary (singular) fit: see ?isSingular
#
# boundary (singular) fit: see ?isSingular
#
# boundary (singular) fit: see ?isSingular
#
# boundary (singular) fit: see ?isSingular
#
# boundary (singular) fit: see ?isSingular
#
# boundary (singular) fit: see ?isSingular
#
# boundary (singular) fit: see ?isSingular
#
# boundary (singular) fit: see ?isSingular
#
# boundary (singular) fit: see ?isSingular
#
# boundary (singular) fit: see ?isSingular
#
# boundary (singular) fit: see ?isSingular
#
# boundary (singular) fit: see ?isSingular
#
# boundary (singular) fit: see ?isSingular
#
# boundary (singular) fit: see ?isSingular
#
# boundary (singular) fit: see ?isSingular
#
# boundary (singular) fit: see ?isSingular
#
# boundary (singular) fit: see ?isSingular
#
# boundary (singular) fit: see ?isSingular
#
# boundary (singular) fit: see ?isSingular
#
# boundary (singular) fit: see ?isSingular
#
# boundary (singular) fit: see ?isSingular
#
# boundary (singular) fit: see ?isSingular
#
# boundary (singular) fit: see ?isSingular
#
# boundary (singular) fit: see ?isSingular
#
# boundary (singular) fit: see ?isSingular
#
# boundary (singular) fit: see ?isSingular
#
# boundary (singular) fit: see ?isSingular
#
# boundary (singular) fit: see ?isSingular
#
# boundary (singular) fit: see ?isSingular
#
# boundary (singular) fit: see ?isSingular
#
# boundary (singular) fit: see ?isSingular
#
# boundary (singular) fit: see ?isSingular
#
# boundary (singular) fit: see ?isSingular
#
# boundary (singular) fit: see ?isSingular
#
# boundary (singular) fit: see ?isSingular
#
# boundary (singular) fit: see ?isSingular
#
# boundary (singular) fit: see ?isSingular
#
# boundary (singular) fit: see ?isSingular
#
# boundary (singular) fit: see ?isSingular
#
# boundary (singular) fit: see ?isSingular
#
# boundary (singular) fit: see ?isSingular
#
# boundary (singular) fit: see ?isSingular
#
# boundary (singular) fit: see ?isSingular
#
# boundary (singular) fit: see ?isSingular
#
# boundary (singular) fit: see ?isSingular
#
# boundary (singular) fit: see ?isSingular
#
# boundary (singular) fit: see ?isSingular
#
# boundary (singular) fit: see ?isSingular
#
# boundary (singular) fit: see ?isSingular
#
# boundary (singular) fit: see ?isSingular
#
# boundary (singular) fit: see ?isSingular
#
# boundary (singular) fit: see ?isSingular
#
# boundary (singular) fit: see ?isSingular
#
# boundary (singular) fit: see ?isSingular
#
# boundary (singular) fit: see ?isSingular
#
# boundary (singular) fit: see ?isSingular
#
# boundary (singular) fit: see ?isSingular
#
# boundary (singular) fit: see ?isSingular
#
# boundary (singular) fit: see ?isSingular
#
# boundary (singular) fit: see ?isSingular
#
# boundary (singular) fit: see ?isSingular
#
# boundary (singular) fit: see ?isSingular
#
# boundary (singular) fit: see ?isSingular
#
# boundary (singular) fit: see ?isSingular
#
# boundary (singular) fit: see ?isSingular
#
# boundary (singular) fit: see ?isSingular
#
# boundary (singular) fit: see ?isSingular
#
# boundary (singular) fit: see ?isSingular
#
# boundary (singular) fit: see ?isSingular
#
# boundary (singular) fit: see ?isSingular
#
# boundary (singular) fit: see ?isSingular
#
# boundary (singular) fit: see ?isSingular
#
# boundary (singular) fit: see ?isSingular
#
# boundary (singular) fit: see ?isSingular
#
# boundary (singular) fit: see ?isSingular
#
# boundary (singular) fit: see ?isSingular
#
# boundary (singular) fit: see ?isSingular
#
# boundary (singular) fit: see ?isSingular
#
# boundary (singular) fit: see ?isSingular
#
# boundary (singular) fit: see ?isSingular
#
# boundary (singular) fit: see ?isSingular
#
# boundary (singular) fit: see ?isSingular
#
# boundary (singular) fit: see ?isSingular
#
# boundary (singular) fit: see ?isSingular
#
# boundary (singular) fit: see ?isSingular
#
# boundary (singular) fit: see ?isSingular
#
# boundary (singular) fit: see ?isSingular
#
# boundary (singular) fit: see ?isSingular
#
# boundary (singular) fit: see ?isSingular
#
# boundary (singular) fit: see ?isSingular
#
# boundary (singular) fit: see ?isSingular
#
# boundary (singular) fit: see ?isSingular
#
# boundary (singular) fit: see ?isSingular
#
# boundary (singular) fit: see ?isSingular
#
# boundary (singular) fit: see ?isSingular
#
# boundary (singular) fit: see ?isSingular
#
# boundary (singular) fit: see ?isSingular
#
# boundary (singular) fit: see ?isSingular
#
# boundary (singular) fit: see ?isSingular
#
# boundary (singular) fit: see ?isSingular
#
# boundary (singular) fit: see ?isSingular
#
# boundary (singular) fit: see ?isSingular
#
# boundary (singular) fit: see ?isSingular
#
# boundary (singular) fit: see ?isSingular
#
# boundary (singular) fit: see ?isSingular
#
# boundary (singular) fit: see ?isSingular
#
# boundary (singular) fit: see ?isSingular
#
# boundary (singular) fit: see ?isSingular
#
# boundary (singular) fit: see ?isSingular
#
# boundary (singular) fit: see ?isSingular
#
# boundary (singular) fit: see ?isSingular
#
# boundary (singular) fit: see ?isSingular
#
# boundary (singular) fit: see ?isSingular
#
# boundary (singular) fit: see ?isSingular
#
# boundary (singular) fit: see ?isSingular
#
# boundary (singular) fit: see ?isSingular
#
# boundary (singular) fit: see ?isSingular
#
# boundary (singular) fit: see ?isSingular
#
# boundary (singular) fit: see ?isSingular
#
# boundary (singular) fit: see ?isSingular
#
# boundary (singular) fit: see ?isSingular
#
# boundary (singular) fit: see ?isSingular
#
# boundary (singular) fit: see ?isSingular
#
# boundary (singular) fit: see ?isSingular
#
# boundary (singular) fit: see ?isSingular
#
# boundary (singular) fit: see ?isSingular
#
# boundary (singular) fit: see ?isSingular
#
# boundary (singular) fit: see ?isSingular
#
# boundary (singular) fit: see ?isSingular
#
# boundary (singular) fit: see ?isSingular
#
# boundary (singular) fit: see ?isSingular
#
# boundary (singular) fit: see ?isSingular
#
# boundary (singular) fit: see ?isSingular
#
# boundary (singular) fit: see ?isSingular
#
# boundary (singular) fit: see ?isSingular
#
# boundary (singular) fit: see ?isSingular
#
# boundary (singular) fit: see ?isSingular
#
# boundary (singular) fit: see ?isSingular
#
# boundary (singular) fit: see ?isSingular
#
# boundary (singular) fit: see ?isSingular
#
# boundary (singular) fit: see ?isSingular
#
# boundary (singular) fit: see ?isSingular
#
# boundary (singular) fit: see ?isSingular
#
# boundary (singular) fit: see ?isSingular
#
# boundary (singular) fit: see ?isSingular
#
# boundary (singular) fit: see ?isSingular
#
# boundary (singular) fit: see ?isSingular
#
# boundary (singular) fit: see ?isSingular
#
# boundary (singular) fit: see ?isSingular
#
# boundary (singular) fit: see ?isSingular
#
# boundary (singular) fit: see ?isSingular
#
# boundary (singular) fit: see ?isSingular
#
# boundary (singular) fit: see ?isSingular
#
# boundary (singular) fit: see ?isSingular
#
# boundary (singular) fit: see ?isSingular
#
# boundary (singular) fit: see ?isSingular
#
# boundary (singular) fit: see ?isSingular
#
# boundary (singular) fit: see ?isSingular
#
# boundary (singular) fit: see ?isSingular
#
# boundary (singular) fit: see ?isSingular
#
# boundary (singular) fit: see ?isSingular
#
# boundary (singular) fit: see ?isSingular
#
# boundary (singular) fit: see ?isSingular
#
# boundary (singular) fit: see ?isSingular
#
# boundary (singular) fit: see ?isSingular
#
# boundary (singular) fit: see ?isSingular
#
# boundary (singular) fit: see ?isSingular
#
# boundary (singular) fit: see ?isSingular
#
# boundary (singular) fit: see ?isSingular
#
# boundary (singular) fit: see ?isSingular
#
# boundary (singular) fit: see ?isSingular
#
# boundary (singular) fit: see ?isSingular
#
# boundary (singular) fit: see ?isSingular
#
# boundary (singular) fit: see ?isSingular
#
# boundary (singular) fit: see ?isSingular
#
# boundary (singular) fit: see ?isSingular
#
# boundary (singular) fit: see ?isSingular
#
# boundary (singular) fit: see ?isSingular
#
# boundary (singular) fit: see ?isSingular

# %%
png(file.path(dirloc, 'PVCA_sva1-2.png'), width=800, height=400)
bp <- barplot(pvcaObj_sva2$dat,
              ylab=expression(bold("Weighted Average Proportion Variance")),
              ylim=c(0,1.1), col=c("navy"), las=2, font=4,
              main="Principal Variant Component Analysis Estimation")
axis(1,at=bp,labels=pvcaObj_sva2$label,cex.axis=1,las=2,font=4)
values <- pvcaObj_sva2$dat
new_values <- round(values,3)
text(bp,pvcaObj_sva2$dat,labels=new_values,pos=3,cex=1,font=4)
dev.off()
# Out:
# png
#   2

# %%
# In summary, SV1 and SV2 capture a lot of the variance that was in LibraryPool and TIN...
